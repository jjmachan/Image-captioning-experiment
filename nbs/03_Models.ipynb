# %%
# default_exp models

# %%
#export
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # models
#
# > API details:

# %%
# append our Aeye package
# TODO: fix this import issue when using the package.
import sys 
sys.path.append('../Aeye')

from preprocessing import Lang, tensorForImageCaption, get_preprocessed_data, SOS_token, EOS_token

# %%
feature_dict, sentence_list, lang = get_preprocessed_data('train')
sentence_list = random.sample(sentence_list, len(sentence_list))

# %%
img, sent = tensorForImageCaption(feature_dict, sentence_list[0], lang)

# %%
sentence_list
# Out:
# [('2478929971_9eb6c074b6.jpg',
#   ['a',
#    'group',
#    'of',
#    'boys',
#    'and',
#    'girls',
#    'sit',
#    'and',
#    'talk',
#    'together',
#    'under',
#    'a',
#    'tree']),
#  ('3229821595_77ace81c6b.jpg',
#   ['a',
#    'group',
#    'of',
#    'people',
#    'are',
#    'standing',
#    'on',
#    'a',
#    'ledge',
#    'overlooking',
#    'low',
#    'clouds']),
#  ('241347803_afb04b12c4.jpg',
#   ['this',
#    'football',
#    'team',
#    'wears',
#    'red',
#    'shirts',
#    'and',
#    'red',
#    'helmets']),
#  ('894928353_002a3d5f06.jpg',
#   ['the', 'three', 'children', 'are', 'playing', 'on', 'the', 'rails']),
#  ('1247181182_35cabd76f3.jpg',
#   ['the',
#    'man',
#    'is',
#    'sitting',
#    'at',
#    'the',
#    'top',
#    'of',
#    'a',
#    'rocky',
#    'mountain']),
#  ('420355149_f2076770df.jpg',
#   ['a',
#    'little',
#    'kid',
#    'dressed',
#    'in',
#    'blue',
#    'playing',
#    'in',
#    'a',
#    'boat']),
#  ('3601569729_bf4bf82768.jpg',
#   ['there',
#    'are',
#    'riders',
#    'and',
#    'horses',
#    'in',
#    'a',
#    'horse',
#    'race',
#    'going',
#    'around',
#    'a',
#    'track']),
#  ('2394003437_184a838aa9.jpg',
#   ['the',
#    'child',
#    'in',
#    'the',
#    'green',
#    'shirt',
#    'is',
#    'on',
#    'a',
#    'machine',
#    'with',
#    'wheels']),
#  ('3043685748_130db75e3b.jpg',
#   ['numbered',
#    'motorcycles',
#    'round',
#    'the',
#    'turn',
#    'on',
#    'a',
#    'racetrack',
#    'with',
#    'billboards',
#    'in',
#    'the',
#    'background']),
#  ('3690107455_0fdb4ecee7.jpg',
#   ['a', 'woman', 'walks', 'across', 'a', 'large', 'rock']),
#  ('2524003134_580e74328b.jpg', ['a', 'dog', 'is', 'in', 'the', 'water']),
#  ('3553374585_25b1bd6970.jpg',
#   ['three',
#    'young',
#    'men',
#    'in',
#    'white',
#    'walking',
#    'near',
#    'tented',
#    'area',
#    'with',
#    'banner',
#    'advertisement']),
#  ('3236677456_75821e3583.jpg',
#   ['a',
#    'brown',
#    'and',
#    'black',
#    'dog',
#    'jumps',
#    'high',
#    'in',
#    'the',
#    'air',
#    'after',
#    'a',
#    'purple',
#    'frisbee']),
#  ('946051430_8db7e4ce09.jpg',
#   ['girls',
#    'in',
#    'swimsuits',
#    'holding',
#    'hands',
#    'and',
#    'leaping',
#    'into',
#    'water']),
#  ('782017931_75d92bb7a4.jpg',
#   ['two',
#    'people',
#    'stand',
#    'against',
#    'the',
#    'railing',
#    'above',
#    'the',
#    'water',
#    'and',
#    'watch',
#    'the',
#    'sunset']),
#  ('2547785434_f227bd3680.jpg',
#   ['a', 'small', 'dog', 'chasing', 'after', 'a', 'bucking', 'cow']),
#  ('2478929971_9eb6c074b6.jpg',
#   ['the',
#    'six',
#    'kids',
#    'are',
#    'in',
#    'the',
#    'shade',
#    'of',
#    'a',
#    'leafy',
#    'green',
#    'tree']),
#  ('3149038044_c7c94688c6.jpg',
#   ['two', 'children', 'are', 'playing', 'flag', 'football', 'together']),
#  ('2951092164_4940b9a517.jpg',
#   ['a',
#    'little',
#    'boy',
#    'and',
#    'a',
#    'little',
#    'girl',
#    'wearing',
#    'water',
#    'wings',
#    'are',
#    'running',
#    'on',
#    'a',
#    'path',
#    'beside',
#    'a',
#    'black',
#    'fence']),
#  ('256283122_a4ef4a17cb.jpg',
#   ['dog',
#    'jumps',
#    'over',
#    'owner',
#    'to',
#    'catch',
#    'smilely',
#    'faced',
#    'frisbee',
#    'while',
#    'spectators',
#    'in',
#    'the',
#    'park',
#    'watch']),
#  ('3677927146_1696f0b075.jpg',
#   ['three', 'dogs', 'moving', 'through', 'grass']),
#  ('3648988742_888a16f600.jpg',
#   ['a',
#    'young',
#    'girl',
#    'wearing',
#    'a',
#    'pink',
#    'hat',
#    'holding',
#    'a',
#    'camera',
#    'up',
#    'to',
#    'her',
#    'face']),
#  ('2878705136_609dfbf318.jpg',
#   ['a',
#    'woman',
#    'in',
#    'a',
#    'blue',
#    'shirt',
#    'and',
#    'tan',
#    'shorts',
#    'sits',
#    'at',
#    'a',
#    'table']),
#  ('2574084102_f2be3f73cb.jpg',
#   ['a',
#    'young',
#    'girl',
#    'wearing',
#    'blue',
#    'is',
#    'jumping',
#    'in',
#    'the',
#    'air']),
#  ('3712742641_641282803e.jpg',
#   ['a', 'dog', 'treads', 'through', 'dark', 'green', 'water']),
#  ('241347214_5f19e7998c.jpg',
#   ['three',
#    'football',
#    'players',
#    'wearing',
#    'red',
#    'jerseys',
#    'are',
#    'on',
#    'the',
#    'field']),
#  ('561179884_8b6b925ef9.jpg',
#   ['a',
#    'man',
#    'is',
#    'trying',
#    'to',
#    'photograph',
#    'a',
#    'rocky',
#    'outcropping']),
#  ('3381038951_225bb163af.jpg',
#   ['a', 'woman', 'pointing', 'at', 'a', 'geyser']),
#  ('2850719435_221f15e951.jpg',
#   ['two',
#    'children',
#    'are',
#    'playing',
#    'on',
#    'a',
#    'teal',
#    'trampoline',
#    'near',
#    'greenery']),
#  ('300371487_daec5d11ab.jpg',
#   ['brown', 'dog', 'chasing', 'a', 'pink', 'ball']),
#  ('2579460386_94c489028d.jpg',
#   ['this', 'dog', 'is', 'jumping', 'through', 'the', 'water']),
#  ('234241682_51d9fabb27.jpg',
#   ['people',
#    'playing',
#    'soccer',
#    'on',
#    'a',
#    'soccer',
#    'field',
#    'during',
#    'sunset']),
#  ('3189002057_3ef61b803e.jpg',
#   ['a',
#    'man',
#    'and',
#    'girl',
#    'are',
#    'walking',
#    'barefoot',
#    'on',
#    'the',
#    'beach',
#    'at',
#    'sunset']),
#  ('514431934_9cf78f05a9.jpg',
#   ['two',
#    'people',
#    'in',
#    'seattle',
#    'looking',
#    'at',
#    'an',
#    'ambulance',
#    'in',
#    'the',
#    'street']),
#  ('3535056297_e16f014cb7.jpg',
#   ['a', 'bunch', 'of', 'people', 'mainly', 'men', 'watching', 'something']),
#  ('2977246776_b14be8290d.jpg',
#   ['a',
#    'small',
#    'child',
#    'shows',
#    'excitement',
#    'on',
#    'a',
#    'swing',
#    'set',
#    'at',
#    'the',
#    'park']),
#  ('3677613006_4689cb8e4e.jpg',
#   ['the',
#    'girl',
#    'is',
#    'wearing',
#    'headphones',
#    'and',
#    'holding',
#    'a',
#    'michael',
#    'jackson',
#    'album']),
#  ('2662816021_ac474e0fde.jpg',
#   ['the',
#    'white',
#    'dog',
#    'is',
#    'standing',
#    'in',
#    'the',
#    'water',
#    'with',
#    'a',
#    'stick',
#    'in',
#    'its',
#    'mouth']),
#  ('3305767464_d64a336f60.jpg',
#   ['a',
#    'man',
#    'in',
#    'a',
#    'white',
#    'headband',
#    'plays',
#    'the',
#    'drums',
#    'at',
#    'a',
#    'concert']),
#  ('3168796547_0c14b368f9.jpg',
#   ['two', 'kids', 'sit', 'on', 'a', 'statue', 'of', 'a', 'deer']),
#  ('3130093622_362f32f2bb.jpg',
#   ['a', 'german', 'shephard', 'plays', 'in', 'the', 'snow']),
#  ('366713533_bd6d48cf02.jpg',
#   ['two',
#    'men',
#    'a',
#    'woman',
#    'and',
#    'two',
#    'young',
#    'boys',
#    'stand',
#    'in',
#    'front',
#    'of',
#    'a',
#    'large',
#    'gathering',
#    'of',
#    'people',
#    'outside',
#    'a',
#    'building']),
#  ('3168841415_c0705a327a.jpg',
#   ['a', 'boy', 'in', 'a', 'brown', 'shirt', 'throwing', 'a', 'frisbee']),
#  ('2272426567_9e9fb79db0.jpg',
#   ['a', 'dog', 'walks', 'through', 'the', 'snow', 'in', 'the', 'daylight']),
#  ('2070831523_5035d5537e.jpg',
#   ['a',
#    'woman',
#    'rides',
#    'her',
#    'bike',
#    'down',
#    'the',
#    'street',
#    'in',
#    'the',
#    'fall']),
#  ('2127209046_94711c747b.jpg',
#   ['hikers', 'walking', 'up', 'red', 'clay', 'path']),
#  ('468141298_3154d717e1.jpg',
#   ['cobblestone', 'street', 'and', 'line', 'of', 'storefronts']),
#  ('3082474922_9c3533eaf6.jpg',
#   ['boy',
#    'wearing',
#    'red',
#    'hat',
#    'blue',
#    'jacket',
#    'pushing',
#    'plow',
#    'in',
#    'snow']),
#  ('2595713720_30534e8de2.jpg',
#   ['a',
#    'little',
#    'girl',
#    'in',
#    'a',
#    'pink',
#    'cowgirl',
#    'hat',
#    'and',
#    'blue',
#    'cast',
#    'over',
#    'her',
#    'arm',
#    'is',
#    'walking',
#    'a',
#    'sheep']),
#  ('3165826902_6bf9c4bdb2.jpg',
#   ['young',
#    'man',
#    'with',
#    'white',
#    'helmet',
#    'is',
#    'rollerblading',
#    'on',
#    'a',
#    'ledge']),
#  ('296873864_4de75de261.jpg',
#   ['a',
#    'golden',
#    'retriever',
#    'is',
#    'biting',
#    'a',
#    'branch',
#    'in',
#    'a',
#    'yard']),
#  ('2273871383_1ddb3562ea.jpg',
#   ['an', 'elderly', 'man', 'standing', 'near', 'a', 'younger', 'man']),
#  ('2959737718_31203fddb5.jpg',
#   ['three',
#    'men',
#    'from',
#    'two',
#    'teams',
#    'are',
#    'in',
#    'the',
#    'air',
#    'colliding',
#    'and',
#    'there',
#    'is',
#    'a',
#    'soccer',
#    'ball',
#    'above',
#    'them']),
#  ('3032790880_d216197d55.jpg',
#   ['the',
#    'soccer',
#    'player',
#    'in',
#    'purple',
#    'keeps',
#    'the',
#    'ball',
#    'from',
#    'the',
#    'man',
#    'in',
#    'red']),
#  ('1527513023_3d8152b379.jpg',
#   ['a',
#    'little',
#    'boy',
#    'plays',
#    'with',
#    'a',
#    'water',
#    'toy',
#    'while',
#    'others',
#    'watch']),
#  ('3079917032_3cfacb2fd7.jpg',
#   ['a',
#    'woman',
#    'in',
#    'a',
#    'red',
#    'sweater',
#    'walks',
#    'by',
#    'two',
#    'younger',
#    'women',
#    'talking',
#    'near',
#    'a',
#    'busy',
#    'street']),
#  ('542405691_0594b1ce72.jpg',
#   ['a', 'boy', 'kicks', 'a', 'ball', 'in', 'his', 'living', 'room']),
#  ('3662909101_21b9e59a3e.jpg',
#   ['a', 'black', 'dog', 'jumps', 'over', 'a', 'show', 'jumping', 'hurdle']),
#  ('3222496967_45d468ee66.jpg',
#   ['a',
#    'woman',
#    'with',
#    'a',
#    'newspaper',
#    'is',
#    'looking',
#    'at',
#    'a',
#    'man',
#    'with',
#    'a',
#    'side',
#    'pack',
#    'on',
#    'a',
#    'street',
#    'sidewalk']),
#  ('2572101672_4d699c8713.jpg',
#   ['the', 'man', 'is', 'standing', 'next', 'to', 'a', 'bird', 'cage']),
#  ('1576185717_f841ddc3da.jpg',
#   ['a',
#    'boy',
#    'and',
#    'yellow',
#    'and',
#    'girl',
#    'in',
#    'red',
#    'playing',
#    'cricket']),
#  ('824123145_59243e504e.jpg',
#   ['three', 'woman', 'walk', 'on', 'the', 'sidewalk']),
#  ('2266142543_b2de18c081.jpg',
#   ['a',
#    'man',
#    'with',
#    'a',
#    'baseball',
#    'cap',
#    'on',
#    'backwards',
#    'is',
#    'holding',
#    'a',
#    'cup']),
#  ('408748500_e8dc8c0c4f.jpg',
#   ['the',
#    'boy',
#    'is',
#    'dressed',
#    'in',
#    'a',
#    'red',
#    'coat',
#    'and',
#    'stands',
#    'next',
#    'to',
#    'a',
#    'statue']),
#  ('3655773435_c234e94820.jpg',
#   ['a', 'black', 'dog', 'swims', 'in', 'a', 'large', 'pool']),
#  ('3262475923_f1f77fcd9f.jpg',
#   ['two',
#    'men',
#    'in',
#    'wintry',
#    'athletic',
#    'clothing',
#    'play',
#    'ultimate',
#    'frisbee']),
#  ('317641829_ab2607a6c0.jpg',
#   ['a', 'man', 'standing', 'near', 'a', 'street', 'corner']),
#  ('3616638478_641d02183d.jpg',
#   ['two', 'woman', 'wearing', 'skirts', 'stand', 'together', 'and', 'smile']),
#  ('2466171114_3fa51415a7.jpg',
#   ['a', 'brown', 'dog', 'is', 'carrying', 'a', 'toy', 'in', 'its', 'mouth']),
#  ('3018847610_0bf4d7e43d.jpg',
#   ['a',
#    'professional',
#    'wrestler',
#    'takes',
#    'a',
#    'flying',
#    'leap',
#    'onto',
#    'another',
#    'wrestler']),
#  ('3002920707_5d2e6e6aac.jpg', ['a', 'boy', 'and', 'girl', 'are', 'dancing']),
#  ('2911919938_6bb6587a36.jpg', ['a', 'boy', 'getting', 'a', 'shower']),
#  ('3726019124_f302b3d48a.jpg',
#   ['a', 'bike', 'in', 'a', 'field', 'and', 'two', 'kites']),
#  ('3286111436_891ae7dab9.jpg',
#   ['a',
#    'basketball',
#    'player',
#    'for',
#    'north',
#    'carolina',
#    'moves',
#    'with',
#    'the',
#    'ball',
#    'in',
#    'hand']),
#  ('2916586390_664f0139ea.jpg',
#   ['a',
#    'woman',
#    'in',
#    'purple',
#    'pants',
#    'is',
#    'using',
#    'a',
#    'green',
#    'hula',
#    'hoop']),
#  ('3098824948_23c31df031.jpg',
#   ['a', 'man', 'and', 'bride', 'walk', 'down', 'the', 'aisle']),
#  ('2429272699_8a9699775e.jpg',
#   ['a',
#    'man',
#    'in',
#    'black',
#    'with',
#    'a',
#    'scarf',
#    'walks',
#    'down',
#    'a',
#    'street']),
#  ('3054989420_3e755ca352.jpg',
#   ['children', 'in', 'coats', 'playing', 'in', 'fall', 'leaves']),
#  ('3485486737_953f9d3be2.jpg',
#   ['photographer', 'shooting', 'picture', 'of', 'yellow', 'bus']),
#  ('487071033_27e460a1b9.jpg',
#   ['people',
#    'watching',
#    'a',
#    'guy',
#    'in',
#    'a',
#    'black',
#    'and',
#    'green',
#    'baseball',
#    'cap',
#    'skateboarding']),
#  ('2081615901_13092cac56.jpg',
#   ['two',
#    'girls',
#    'wearing',
#    'red',
#    'pants',
#    'black',
#    'pants',
#    'and',
#    'sandals',
#    'are',
#    'climbing',
#    'a',
#    'chain',
#    'link',
#    'fence']),
#  ('2921430836_3b4d062238.jpg',
#   ['a',
#    'referee',
#    'is',
#    'watching',
#    'a',
#    'professional',
#    'football',
#    'game',
#    'in',
#    'the',
#    'grass']),
#  ('3692836015_d11180727b.jpg',
#   ['people', 'in', 'matching', 'outfits', 'next', 'to', 'a', 'canon']),
#  ('3095137758_bdd1e613dd.jpg',
#   ['santa', 'is', 'pulled', 'in', 'a', 'carriage', 'in', 'a', 'parade']),
#  ('2916009941_34a0013803.jpg',
#   ['a',
#    'young',
#    'child',
#    'leans',
#    'against',
#    'a',
#    'rail',
#    'on',
#    'a',
#    'crowded',
#    'wooden',
#    'bridge']),
#  ('3331797838_b3e33dbe17.jpg',
#   ['two',
#    'people',
#    'wearing',
#    'long',
#    'sleeves',
#    'and',
#    'helmets',
#    'ride',
#    'bikes',
#    'downhill']),
#  ('222369445_5b6af347dd.jpg',
#   ['two',
#    'surfers',
#    'carry',
#    'their',
#    'boards',
#    'to',
#    'the',
#    'end',
#    'of',
#    'a',
#    'walkway',
#    'to',
#    'join',
#    'the',
#    'others',
#    'in',
#    'the',
#    'water']),
#  ('2968216482_ede65b20a8.jpg',
#   ['a',
#    'biker',
#    'patiently',
#    'waits',
#    'as',
#    'his',
#    'friend',
#    'bikes',
#    'ahead',
#    'of',
#    'him']),
#  ('697778778_b52090709d.jpg',
#   ['three',
#    'people',
#    'rock',
#    'climbing',
#    'in',
#    'matching',
#    'clothes',
#    'beside',
#    'a',
#    'small',
#    'waterfall']),
#  ('258476074_f28f4a1ae6.jpg',
#   ['a',
#    'line',
#    'of',
#    'off',
#    'road',
#    'vehicles',
#    'is',
#    'parked',
#    'on',
#    'the',
#    'hill',
#    'outside',
#    'a',
#    'wooded',
#    'area']),
#  ('1244140539_da4804d828.jpg',
#   ['a', 'small', 'dog', 'is', 'sitting', 'on', 'white', 'carpet']),
#  ('2264316030_600e55748d.jpg',
#   ['a', 'brown', 'dog', 'is', 'running', 'through', 'snowy', 'woodland']),
#  ('2285152690_3fb93f65f1.jpg',
#   ['a', 'basketball', 'player', 'in', 'a', 'duke', 'uniform', 'looks', 'up']),
#  ('3039209547_81cc93fbec.jpg',
#   ['a',
#    'distorted',
#    'picture',
#    'of',
#    'two',
#    'men',
#    'walking',
#    'in',
#    'the',
#    'street']),
#  ('3425071001_e7c9809ef2.jpg',
#   ['a',
#    'teenage',
#    'boy',
#    'hits',
#    'a',
#    'tennis',
#    'ball',
#    'with',
#    'a',
#    'racket']),
#  ('3034585889_388d6ffcc0.jpg',
#   ['a',
#    'person',
#    'is',
#    'riding',
#    'their',
#    'motorbike',
#    'and',
#    'a',
#    'person',
#    'in',
#    'a',
#    'bright',
#    'yellow',
#    'jacket',
#    'is',
#    'watching',
#    'someone',
#    'fall',
#    'off',
#    'their',
#    'bike']),
#  ('3677734351_63d60844cb.jpg',
#   ['a',
#    'man',
#    'and',
#    'woman',
#    'are',
#    'walking',
#    'whilst',
#    'holding',
#    'hands',
#    'down',
#    'a',
#    'leafy',
#    'lane']),
#  ('387078972_514a38dc33.jpg',
#   ['a', 'white', 'dog', 'walks', 'in', 'the', 'snow']),
#  ('2065309381_705b774f51.jpg',
#   ['a',
#    'skier',
#    'rapidly',
#    'descending',
#    'a',
#    'steep',
#    'snow',
#    'covered',
#    'hill']),
#  ('3636543173_15f56515e5.jpg',
#   ['two', 'young', 'men', 'are', 'posing', 'for', 'the', 'camera']),
#  ('2696060728_3043cfc38c.jpg',
#   ['a',
#    'girl',
#    'stands',
#    'on',
#    'a',
#    'surfboard',
#    'which',
#    'a',
#    'man',
#    'is',
#    'standing',
#    'behind',
#    'and',
#    'holding']),
#  ('436013859_793d870b6f.jpg', ['brown', 'dog', 'plays', 'with', 'frisbee']),
#  ('2188192752_09d9fc5431.jpg',
#   ['a', 'boy', 'runs', 'while', 'another', 'family', 'is', 'standing', 'by']),
#  ('3690189273_927d42ff43.jpg',
#   ['a',
#    'woman',
#    'is',
#    'running',
#    'a',
#    'race',
#    'carrying',
#    'a',
#    'plastic',
#    'bottle']),
#  ('498794783_cc2ac62b47.jpg',
#   ['two',
#    'girls',
#    'in',
#    'colourful',
#    'dresses',
#    'blowing',
#    'bubbles',
#    'at',
#    'a',
#    'park']),
#  ('3359587274_4a2b140b84.jpg',
#   ['a',
#    'person',
#    'attached',
#    'to',
#    'a',
#    'parasail',
#    'and',
#    'wearing',
#    'equipment',
#    'on',
#    'his',
#    'feet',
#    'is',
#    'suspended',
#    'in',
#    'midair',
#    'over',
#    'a',
#    'snowy',
#    'landscape',
#    'while',
#    'silhouetted',
#    'against',
#    'a',
#    'sunny',
#    'blue',
#    'sky']),
#  ('1287982439_6578006e22.jpg',
#   ['a',
#    'dog',
#    'runs',
#    'through',
#    'the',
#    'water',
#    'as',
#    'he',
#    'looks',
#    'up',
#    'at',
#    'the',
#    'sky',
#    'with',
#    'his',
#    'mouth',
#    'open']),
#  ('3724150944_fc62e8d5e0.jpg', ['four', 'boys', 'playing', 'soccer']),
#  ('3413019648_e787f0cb88.jpg',
#   ['a',
#    'man',
#    'in',
#    'a',
#    'green',
#    'kayak',
#    'paddles',
#    'down',
#    'some',
#    'rapids',
#    'in',
#    'front',
#    'of',
#    'a',
#    'waterfall']),
#  ('2337377811_8c81b40a64.jpg',
#   ['a', 'small', 'girl', 'trots', 'through', 'the', 'snow']),
#  ('2554570943_122da6438f.jpg',
#   ['a',
#    'child',
#    'in',
#    'a',
#    'yellow',
#    'shirt',
#    'and',
#    'blue',
#    'jeans',
#    'climbs',
#    'through',
#    'a',
#    'red',
#    'playground',
#    'tunnel']),
#  ('2836808985_b26e4ca09e.jpg',
#   ['a',
#    'young',
#    'man',
#    'in',
#    'a',
#    'plaid',
#    'shirts',
#    'sits',
#    'on',
#    'the',
#    'deck',
#    'of',
#    'a',
#    'boat']),
#  ('1813777902_07d1d4b00c.jpg',
#   ['a', 'boy', 'dressed', 'as', 'a', 'pirate', 'smiles', 'largley']),
#  ('3467941308_ae6989e29c.jpg',
#   ['a', 'brown', 'dog', 'is', 'gallopsing', 'through', 'the', 'grass']),
#  ('285586547_c81f8905a1.jpg',
#   ['a',
#    'man',
#    'and',
#    'a',
#    'dog',
#    'who',
#    'are',
#    'both',
#    'wearing',
#    'sunglasses',
#    'take',
#    'a',
#    'ride']),
#  ('3306212559_731ba9bd05.jpg',
#   ['four', 'men', 'with', 'a', 'sunset', 'in', 'background']),
#  ('2445654384_4ee3e486e1.jpg',
#   ['a',
#    'person',
#    'helping',
#    'a',
#    'small',
#    'baby',
#    'down',
#    'a',
#    'blue',
#    'slide']),
#  ('428485639_a82635d6ee.jpg',
#   ['a',
#    'little',
#    'girl',
#    'wearing',
#    'a',
#    'navy',
#    'skirt',
#    'is',
#    'climbing',
#    'on',
#    'some',
#    'silver',
#    'poles']),
#  ('3126681108_f88128699c.jpg',
#   ['the',
#    'child',
#    'is',
#    'shoveling',
#    'deep',
#    'white',
#    'snow',
#    'near',
#    'the',
#    'house']),
#  ('95783195_e1ba3f57ca.jpg',
#   ['a', 'woman', 'crossing', 'a', 'wooden', 'link', 'wire', 'bridge']),
#  ('1445123245_c7b9db0e0c.jpg',
#   ['a',
#    'small',
#    'brown',
#    'and',
#    'black',
#    'dog',
#    'plays',
#    'with',
#    'a',
#    'colorful',
#    'caterpillar',
#    'toy',
#    'on',
#    'a',
#    'tan',
#    'burbur',
#    'carpet']),
#  ('3446191973_1db572ed8a.jpg',
#   ['peolple',
#    'wearing',
#    'hawaiian',
#    'shirts',
#    'hold',
#    'buckets',
#    'by',
#    'the',
#    'water']),
#  ('530454257_66d58b49ee.jpg',
#   ['small',
#    'boy',
#    'looking',
#    'at',
#    'a',
#    'display',
#    'of',
#    'yellow',
#    'rubber',
#    'ducks']),
#  ('429283612_37f6e7fb7f.jpg',
#   ['two', 'people', 'take', 'in', 'the', 'view', 'from', 'a', 'hillside']),
#  ('2462702522_1b25654762.jpg',
#   ['a', 'small', 'boy', 'lifts', 'a', 'red', 'and', 'blue', 'ball']),
#  ('2606433181_f8f9d38579.jpg', ['two', 'dogs', 'play', 'in', 'grass']),
#  ('1931690777_897a7d8ab6.jpg',
#   ['four',
#    'boys',
#    'doing',
#    'a',
#    'cannonball',
#    'jump',
#    'in',
#    'unison',
#    'into',
#    'the',
#    'pool']),
#  ('2998024845_1529c11694.jpg',
#   ['a',
#    'man',
#    'wearing',
#    'an',
#    'orange',
#    'suit',
#    'riding',
#    'a',
#    'bicycle',
#    'in',
#    'a',
#    'race']),
#  ('3455419642_894d03f153.jpg',
#   ['the',
#    'black',
#    'dog',
#    'is',
#    'jumping',
#    'up',
#    'at',
#    'the',
#    'yellow',
#    'ball',
#    'being',
#    'held',
#    'by',
#    'the',
#    'man']),
#  ('3381392182_db2c42430e.jpg',
#   ['a',
#    'person',
#    'wearing',
#    'a',
#    'lkievely',
#    'outfit',
#    'dancing',
#    'on',
#    'some',
#    'concrete']),
#  ('2229509318_be3fef006b.jpg',
#   ['a',
#    'large',
#    'dog',
#    'is',
#    'jumping',
#    'up',
#    'at',
#    'the',
#    'girl',
#    'wearing',
#    'a',
#    'pink',
#    'jacket']),
#  ('2764732789_1392e962d0.jpg',
#   ['a', 'dog', 'runs', 'in', 'a', 'field', 'of', 'brown', 'grass']),
#  ('3279228339_71deaa3d9b.jpg',
#   ['a', 'man', 'sits', 'in', 'a', 'booth', 'at', 'a', 'diner']),
#  ('2870426310_4d59795032.jpg',
#   ['three',
#    'little',
#    'children',
#    'in',
#    'a',
#    'grassy',
#    'yard',
#    'running',
#    'towards',
#    'the',
#    'camera']),
#  ('3053785363_50392f2c53.jpg',
#   ['five',
#    'female',
#    'hockey',
#    'players',
#    'are',
#    'scrambling',
#    'for',
#    'the',
#    'ball',
#    'around',
#    'the',
#    'goal',
#    'mouth']),
#  ('2363540508_9dd1ccf7c7.jpg',
#   ['a', 'young', 'girl', 'going', 'down', 'a', 'tube', 'slide']),
#  ('1398606571_f543f7698a.jpg',
#   ['young',
#    'girl',
#    'in',
#    'pink',
#    'and',
#    'green',
#    'bikini',
#    'swimming',
#    'with',
#    'a',
#    'rubber',
#    'ring']),
#  ('121800200_bef08fae5f.jpg',
#   ['many',
#    'people',
#    'are',
#    'climbing',
#    'the',
#    'mountain',
#    'surrounded',
#    'by',
#    'pretty',
#    'green',
#    'trees']),
#  ('3527184455_1a9c074ff2.jpg',
#   ['two',
#    'adults',
#    'and',
#    'two',
#    'children',
#    'pose',
#    'on',
#    'a',
#    'park',
#    'bench']),
#  ('2129430111_338a94f8fb.jpg',
#   ['a',
#    'backpacker',
#    'is',
#    'walking',
#    'in',
#    'front',
#    'of',
#    'a',
#    'mountain',
#    'with',
#    'arms',
#    'crossed']),
#  ('109823394_83fcb735e1.jpg', ['three', 'people', 'drive', 'atvs']),
#  ('1937262236_cbf5bfa101.jpg',
#   ['two', 'dogs', 'fighting', 'over', 'a', 'pink', 'and', 'red', 'toy']),
#  ('3581538034_783b7d0d09.jpg',
#   ['a', 'water', 'boarder', 'being', 'towed', 'during', 'a', 'jump']),
#  ('2864340145_d28b842faf.jpg',
#   ['a', 'dark', 'dog', 'is', 'in', 'a', 'body', 'of', 'water']),
#  ('2097420505_439f63c863.jpg',
#   ['a', 'man', 'with', 'a', 'camera', 'crouching', 'on', 'ice']),
#  ('95783195_e1ba3f57ca.jpg',
#   ['a',
#    'hiker',
#    'navigates',
#    'a',
#    'rope',
#    'and',
#    'wood',
#    'bridge',
#    'over',
#    'a',
#    'large',
#    'dry',
#    'ravine']),
#  ('3408130183_f038bdaa4f.jpg',
#   ['a',
#    'black',
#    'and',
#    'a',
#    'brown',
#    'dog',
#    'are',
#    'walking',
#    'through',
#    'the',
#    'woods']),
#  ('3384528359_e920154177.jpg',
#   ['a',
#    'large',
#    'gray',
#    'and',
#    'white',
#    'bird',
#    'begins',
#    'to',
#    'take',
#    'flight']),
#  ('3205336477_037d4b6bd9.jpg',
#   ['two', 'young', 'men', 'competing', 'in', 'a', 'wrestling', 'tournament']),
#  ('1449370354_380c4123c9.jpg', ['young', 'boys', 'running', 'on', 'grass']),
#  ('539667015_fd0a3bea07.jpg',
#   ['a',
#    'girl',
#    'is',
#    'doing',
#    'the',
#    'splits',
#    'in',
#    'the',
#    'air',
#    'in',
#    'front',
#    'of',
#    'some',
#    'trees']),
#  ('3477683327_d9e6a2a64f.jpg',
#   ['two', 'men', 'are', 'fly', 'fishing', 'in', 'a', 'low', 'murky', 'pond']),
#  ('3248408149_41a8dd90d3.jpg',
#   ['a',
#    'large',
#    'dog',
#    'plays',
#    'in',
#    'the',
#    'sand',
#    'with',
#    'a',
#    'small',
#    'dog']),
#  ('1562478333_43d13e5427.jpg',
#   ['man', 'setting', 'up', 'camp', 'after', 'canoeing']),
#  ('2613993276_3c365cca12.jpg',
#   ['a',
#    'dog',
#    'in',
#    'a',
#    'grass',
#    'field',
#    'runs',
#    'with',
#    'a',
#    'ball',
#    'in',
#    'its',
#    'mouth']),
#  ('2474918824_88660c7757.jpg',
#   ['a',
#    'man',
#    'wearing',
#    'a',
#    'brown',
#    'sweatshirt',
#    'helps',
#    'a',
#    'man',
#    'in',
#    'red',
#    'climb',
#    'a',
#    'rock']),
#  ('1478294229_7e1c822fea.jpg',
#   ['a', 'man', 'in', 'shorts', 'on', 'a', 'black', 'bicycle']),
#  ('3668259129_e073af1533.jpg', ['a', 'skateboarder', 'doing', 'a', 'jump']),
#  ('3170897628_3054087f8c.jpg',
#   ['there',
#    'are',
#    '2',
#    'shirtless',
#    'boys',
#    'jumping',
#    'up',
#    'from',
#    'some',
#    'water',
#    'looking',
#    'at',
#    'a',
#    'soccer',
#    'ball']),
#  ('3543294190_0037c59607.jpg',
#   ['man',
#    'in',
#    'a',
#    'red',
#    'shirt',
#    'riding',
#    'a',
#    'trick',
#    'bicycle',
#    'on',
#    'only',
#    'the',
#    'rear',
#    'wheel']),
#  ('3437107047_715c60e9c8.jpg',
#   ['two', 'woman', 'smiling', 'standing', 'next', 'to', 'each', 'other']),
#  ('2988439935_7cea05bc48.jpg',
#   ['a',
#    'player',
#    'in',
#    'a',
#    'red',
#    'uniform',
#    'gets',
#    'ready',
#    'to',
#    'kick',
#    'the',
#    'ball',
#    'during',
#    'a',
#    'soccer',
#    'match',
#    'as',
#    'the',
#    'crowd',
#    'watches']),
#  ('2837908308_8bc25c6b02.jpg',
#   ['a', 'dog', 'jumping', 'over', 'an', 'obstacle', 'hurdle']),
#  ('1460352062_d64fb633e0.jpg',
#   ['a', 'woman', 'sits', 'up', 'in', 'the', 'tree', 'looking', 'down']),
#  ('2874728371_ccd6db87f3.jpg',
#   ['a',
#    'large',
#    'brown',
#    'dog',
#    'and',
#    'a',
#    'small',
#    'black',
#    'dog',
#    'stand',
#    'near',
#    'each',
#    'other',
#    'on',
#    'a',
#    'dirt',
#    'patch',
#    'surrounding',
#    'by',
#    'grass',
#    'and',
#    'weeds']),
#  ('2816259113_461f8dedb0.jpg',
#   ['man',
#    'in',
#    'red',
#    'shirt',
#    'watches',
#    'dog',
#    'on',
#    'an',
#    'agility',
#    'course']),
#  ('3532192208_64b069d05d.jpg',
#   ['the',
#    'man',
#    'in',
#    'the',
#    't',
#    'shirt',
#    'with',
#    'a',
#    'gold',
#    'chain',
#    'around',
#    'his',
#    'neck',
#    'is',
#    'in',
#    'a',
#    'room',
#    'with',
#    'three',
#    'others',
#    'people']),
#  ('2289212650_69de7a20b2.jpg',
#   ['a',
#    'white',
#    'and',
#    'a',
#    'white',
#    'dog',
#    'are',
#    'fighting',
#    'over',
#    'a',
#    'stick',
#    'in',
#    'the',
#    'water']),
#  ('315021440_122d56ebd7.jpg',
#   ['two', 'long', 'haired', 'dogs', 'racing', 'down', 'a', 'forest', 'path']),
#  ('3351667846_ac43118ae5.jpg',
#   ['five',
#    'men',
#    'are',
#    'getting',
#    'plates',
#    'of',
#    'rice',
#    'from',
#    'a',
#    'small',
#    'home',
#    'restaurant']),
#  ('2870426310_4d59795032.jpg',
#   ['three',
#    'toddlers',
#    'are',
#    'running',
#    'towards',
#    'the',
#    'camera',
#    'in',
#    'a',
#    'grassy',
#    'yard']),
#  ('3097171315_0ba7d283b1.jpg',
#   ['a',
#    'group',
#    'of',
#    'people',
#    'are',
#    'congregated',
#    'in',
#    'a',
#    'room',
#    'by',
#    'a',
#    'big',
#    'round',
#    'mirror']),
#  ('241109594_3cb90fe2a3.jpg',
#   ['a',
#    'black',
#    'and',
#    'white',
#    'dog',
#    'swimming',
#    'with',
#    'a',
#    'stick',
#    'in',
#    'its',
#    'mouth']),
#  ('716597900_b72c58362c.jpg',
#   ['the', 'boys', 'follow', 'their', 'mother', 'on', 'the', 'beach']),
#  ('3187096035_65dc416291.jpg',
#   ['a', 'group', 'of', 'laughing', 'people', 'on', 'a', 'red', 'couch']),
#  ('134894450_dadea45d65.jpg',
#   ['a', 'shirtless', 'man', 'jumps', 'in', 'a', 'sunny', 'forest']),
#  ('2279945145_8815c59217.jpg',
#   ['a',
#    'black',
#    'and',
#    'white',
#    'dog',
#    'wearing',
#    'collars',
#    'shakes',
#    'off',
#    'on',
#    'the',
#    'dead',
#    'grass']),
#  ('3250593457_9049a73b61.jpg',
#   ['a',
#    'child',
#    'in',
#    'a',
#    'striped',
#    'dress',
#    'and',
#    'a',
#    'woman',
#    'in',
#    'a',
#    'black',
#    'dress']),
#  ('3599568766_9e96def0ef.jpg',
#   ['a', 'white', 'dog', 'runs', 'along', 'the', 'beach', 's', 'shore']),
#  ('2089539651_9e518ec7de.jpg',
#   ['a',
#    'hiker',
#    'with',
#    'two',
#    'hiking',
#    'poles',
#    'stands',
#    'on',
#    'a',
#    'hillside',
#    'with',
#    'a',
#    'view',
#    'of',
#    'the',
#    'city',
#    'below',
#    'him']),
#  ('1141739219_2c47195e4c.jpg',
#   ['a',
#    'very',
#    'colorful',
#    'bus',
#    'is',
#    'pulled',
#    'off',
#    'to',
#    'the',
#    'side',
#    'of',
#    'the',
#    'road',
#    'as',
#    'its',
#    'passengers',
#    'load']),
#  ('2098174172_e57d86ea03.jpg',
#   ['a',
#    'hiker',
#    'is',
#    'standing',
#    'in',
#    'before',
#    'the',
#    'mountain',
#    'holding',
#    'two',
#    'walking',
#    'sticks']),
#  ('2052202553_373dad145b.jpg',
#   ['a',
#    'dog',
#    'is',
#    'running',
#    'through',
#    'a',
#    'creek',
#    'with',
#    'a',
#    'stick',
#    'in',
#    'its',
#    'mouth']),
#  ('3223606402_bb2aa6db95.jpg',
#   ['a', 'skateboarder', 'in', 'the', 'air', 'at', 'the', 'top', 'of', 'ramp']),
#  ('112178718_87270d9b4d.jpg',
#   ['man',
#    'is',
#    'standing',
#    'on',
#    'white',
#    'sand',
#    'and',
#    'holding',
#    'a',
#    'snowboard']),
#  ('2272750492_91e8f67328.jpg',
#   ['a', 'man', 'jumps', 'through', 'the', 'air', 'while', 'snowboarding']),
#  ('3073535022_4af81f360c.jpg',
#   ['a',
#    'woman',
#    'in',
#    'a',
#    'yellow',
#    'shirt',
#    'is',
#    'surfing',
#    'on',
#    'a',
#    'white',
#    'surfboard']),
#  ('1184967930_9e29ce380d.jpg', ['a', 'dog', 'walks', 'through', 'a', 'field']),
#  ('3585495069_33cba06d0a.jpg',
#   ['four', 'people', 'playing', 'ball', 'on', 'a', 'court']),
#  ('489773343_a8aecf7db3.jpg',
#   ['a',
#    'small',
#    'girl',
#    'in',
#    'pink',
#    'and',
#    'blue',
#    'on',
#    'the',
#    'beach',
#    'shows',
#    'something',
#    'to',
#    'two',
#    'black',
#    'dogs']),
#  ('2319087586_919472310f.jpg',
#   ['tattooed',
#    'man',
#    'rubs',
#    'his',
#    'eye',
#    'while',
#    'sitting',
#    'on',
#    'chair',
#    'indoors']),
#  ('3139393607_f0a54ca46d.jpg',
#   ['a',
#    'man',
#    'is',
#    'sliding',
#    'along',
#    'a',
#    'green',
#    'barrier',
#    'on',
#    'his',
#    'snowboard']),
#  ('3692836015_d11180727b.jpg',
#   ['a',
#    'group',
#    'of',
#    'people',
#    'in',
#    'green',
#    'shirts',
#    'push',
#    'a',
#    'cannon',
#    'in',
#    'a',
#    'parade']),
#  ('3304511635_113beaf458.jpg', ['two', 'dancers', 'dance', 'together']),
#  ('504765160_b4b083b293.jpg',
#   ['a', 'woman', 'with', 'a', 'blue', 'shirt', 'and', 'hoop', 'earrings']),
#  ('2849194983_2968c72832.jpg',
#   ['a', 'girl', 'blows', 'a', 'bubble', 'in', 'the', 'water']),
#  ('324355356_859988a710.jpg',
#   ['two',
#    'tan',
#    'dogs',
#    'run',
#    'along',
#    'a',
#    'field',
#    'at',
#    'the',
#    'edge',
#    'of',
#    'a',
#    'woods']),
#  ('3120189281_1938460e85.jpg',
#   ['two',
#    'people',
#    'wearing',
#    'camouflage',
#    'clothing',
#    'in',
#    'the',
#    'snow',
#    'with',
#    'two',
#    'dogs']),
#  ('3331900249_5872e90b25.jpg',
#   ['a', 'man', 'with', 'the', 'monster', 'logo', 'shirt', 'is', 'surfing']),
#  ('2196284168_76417efbec.jpg',
#   ['the', 'baby', 'is', 'holding', 'someone', 's', 'arm']),
#  ('3009047603_28612247d2.jpg',
#   ['a', 'child', 'falling', 'back', 'to', 'kick', 'a', 'soccer', 'ball']),
#  ('3283626303_8e23d4a842.jpg',
#   ['four',
#    'boys',
#    'in',
#    'swimming',
#    'trunks',
#    'lean',
#    'on',
#    'the',
#    'cement',
#    'edge',
#    'of',
#    'a',
#    'pool',
#    'with',
#    'their',
#    'legs',
#    'in',
#    'the',
#    'water']),
#  ('2656987333_80dcc82c05.jpg',
#   ['a',
#    'man',
#    'in',
#    'a',
#    'cowboy',
#    'hat',
#    'being',
#    'stepped',
#    'on',
#    'by',
#    'a',
#    'brown',
#    'horse']),
#  ('2978394277_4572967b97.jpg',
#   ['a',
#    'kid',
#    'jumps',
#    'off',
#    'a',
#    'haystack',
#    'while',
#    'other',
#    'kids',
#    'watch']),
#  ('3394750987_a32ecc477e.jpg',
#   ['a',
#    'man',
#    'is',
#    'skateboarding',
#    'down',
#    'a',
#    'railing',
#    'on',
#    'some',
#    'stairs']),
#  ('3593538248_dffa1a5ed4.jpg',
#   ['several',
#    'hockey',
#    'players',
#    'from',
#    'different',
#    'teams',
#    'and',
#    'a',
#    'referee',
#    'are',
#    'together',
#    'on',
#    'the',
#    'ice']),
#  ('3520079657_b828d96d50.jpg',
#   ['a',
#    'group',
#    'of',
#    'people',
#    'jump',
#    'in',
#    'the',
#    'sand',
#    'at',
#    'the',
#    'beach']),
#  ('3428386573_670f5362f0.jpg',
#   ['a',
#    'man',
#    'wearing',
#    'white',
#    'turns',
#    'to',
#    'hit',
#    'a',
#    'yellow',
#    'tennis',
#    'ball']),
#  ('733752482_ee01a419e5.jpg',
#   ['a',
#    'brown',
#    'and',
#    'white',
#    'dog',
#    'is',
#    'running',
#    'on',
#    'the',
#    'grass']),
#  ('3275065565_9e2a640fbc.jpg',
#   ['two', 'dogs', 'lay', 'upside', 'down', 'on', 'a', 'purple', 'bed']),
#  ('3068945309_ff0973e859.jpg',
#   ['basketball',
#    'player',
#    'in',
#    'white',
#    'uniform',
#    'leaping',
#    'to',
#    'make',
#    'a',
#    'shot',
#    'while',
#    'being',
#    'blocked',
#    'by',
#    'player',
#    'in',
#    'black']),
#  ('3138433655_ea1d59e5b7.jpg',
#   ['a', 'group', 'of', 'young', 'people', 'doing', 'a', 'pose']),
#  ('3162442331_c9711857c6.jpg',
#   ['an',
#    'elephant',
#    'wearing',
#    'a',
#    'colorful',
#    'drap',
#    'carrying',
#    'foliage',
#    'in',
#    'his',
#    'trunk']),
#  ('1527297882_dededc7891.jpg',
#   ['a',
#    'young',
#    'man',
#    'with',
#    'brown',
#    'eyes',
#    'is',
#    'dressed',
#    'up',
#    'like',
#    'jack',
#    'sparrow']),
#  ('1304100320_c8990a1539.jpg',
#   ['two',
#    'dogs',
#    'are',
#    'running',
#    'through',
#    'a',
#    'field',
#    'of',
#    'pink',
#    'flowers']),
#  ('3451345621_fe470d4cf8.jpg',
#   ['a',
#    'man',
#    'wearing',
#    'a',
#    'cowboy',
#    'hat',
#    'holding',
#    'a',
#    'protest',
#    'sign']),
#  ('1801874841_4c12055e2f.jpg',
#   ['a',
#    'little',
#    'dog',
#    'struggles',
#    'with',
#    'a',
#    'man',
#    'holding',
#    'a',
#    'slipper']),
#  ('2576878141_87f25a10f0.jpg',
#   ['a', 'small', 'baby', 'boy', 'sitting', 'on', 'a', 'slide']),
#  ('2650620212_0586016e0d.jpg',
#   ['a', 'black', 'poodle', 'walks', 'on', 'the', 'edge', 'of', 'a', 'pool']),
#  ('684375286_09cc1aa778.jpg',
#   ['two',
#    'dogs',
#    'tug',
#    'at',
#    'the',
#    'same',
#    'item',
#    'while',
#    'wearing',
#    'training',
#    'gear']),
#  ('1193116658_c0161c35b5.jpg',
#   ['there',
#    'is',
#    'a',
#    'girl',
#    'on',
#    'a',
#    'unicycle',
#    'and',
#    'a',
#    'child',
#    'on',
#    'a',
#    'scooter']),
#  ('2111360187_d2505437b7.jpg',
#   ['three', 'children', 'covered', 'in', 'soap', 'bubbles', 'smile']),
#  ('923550133_ac9d7a2932.jpg',
#   ['two', 'girls', 'sit', 'on', 'the', 'edge', 'of', 'a', 'river']),
#  ('472661386_723aae880b.jpg',
#   ['a', 'group', 'of', 'children', 'posing', 'with', 'their', 'certificates']),
#  ('2694178830_116be6a6a9.jpg',
#   ['a', 'woman', 'is', 'black', 'is', 'pole', 'vaulting']),
#  ('3666537170_c4ecda4be8.jpg',
#   ['a',
#    'young',
#    'man',
#    'wearing',
#    'a',
#    'red',
#    'and',
#    'white',
#    'floral',
#    'swinsuit',
#    'falling',
#    'into',
#    'the',
#    'beach']),
#  ('2273871383_1ddb3562ea.jpg',
#   ['a',
#    'older',
#    'man',
#    'in',
#    'beige',
#    'stands',
#    'near',
#    'a',
#    'younger',
#    'man',
#    'in',
#    'blue',
#    'in',
#    'front',
#    'of',
#    'a',
#    'building']),
#  ('1597557856_30640e0b43.jpg',
#   ['a',
#    'brown',
#    'dog',
#    'is',
#    'jumping',
#    'up',
#    'at',
#    'a',
#    'woman',
#    'who',
#    'is',
#    'wearing',
#    'a',
#    'brown',
#    'skirt']),
#  ('2151300603_248a9fe715.jpg',
#   ['a',
#    'woman',
#    'is',
#    'sitting',
#    'at',
#    'a',
#    'desk',
#    'near',
#    'to',
#    'a',
#    'window',
#    'that',
#    'has',
#    'a',
#    'huge',
#    'picture',
#    'of',
#    'a',
#    'hand',
#    'painted',
#    'on',
#    'it']),
#  ('3508051251_82422717b3.jpg',
#   ['a',
#    'man',
#    'in',
#    'worn',
#    'and',
#    'ragged',
#    'clothes',
#    'carries',
#    'a',
#    'satchel',
#    'while',
#    'passin',
#    'a',
#    'tree',
#    'and',
#    'trashcan']),
#  ('2998504949_1022fec53b.jpg',
#   ['a',
#    'man',
#    'in',
#    'a',
#    'blue',
#    'coat',
#    'walks',
#    'a',
#    'small',
#    'white',
#    'animal',
#    'as',
#    'a',
#    'buss',
#    'passes',
#    'in',
#    'the',
#    'background']),
#  ('3387661249_33e5ba0bc5.jpg',
#   ['a',
#    'horse',
#    'and',
#    'dog',
#    'look',
#    'at',
#    'each',
#    'other',
#    'in',
#    'a',
#    'field']),
#  ('544122267_e9e0100bc5.jpg',
#   ['a', 'girl', 'on', 'a', 'swing', 'in', 'the', 'park']),
#  ('2978394277_4572967b97.jpg',
#   ['a',
#    'child',
#    'in',
#    'an',
#    'orange',
#    'shirt',
#    'jumps',
#    'off',
#    'bales',
#    'of',
#    'hay',
#    'while',
#    'other',
#    'children',
#    'watch']),
#  ('3271061953_700b96520c.jpg',
#   ['a',
#    'group',
#    'of',
#    'people',
#    'are',
#    'riding',
#    'in',
#    'the',
#    'back',
#    'of',
#    'a',
#    'truck']),
#  ('425088533_a460dc4617.jpg',
#   ['a',
#    'toddler',
#    'in',
#    'a',
#    'red',
#    'sweatshirt',
#    'and',
#    'grey',
#    'sweatpants',
#    'in',
#    'the',
#    'branches',
#    'of',
#    'a',
#    'tree']),
#  ('3726130458_07df79e969.jpg',
#   ['a',
#    'baseball',
#    'player',
#    'in',
#    'a',
#    'white',
#    'uniform',
#    'is',
#    'walking',
#    'to',
#    'base',
#    'while',
#    'a',
#    'crowd',
#    'of',
#    'people',
#    'watch',
#    'from',
#    'the',
#    'bleachers']),
#  ('522700240_d9af45e60d.jpg',
#   ['the',
#    'dog',
#    'is',
#    'sleeping',
#    'on',
#    'top',
#    'of',
#    'the',
#    'bed',
#    'covered',
#    'by',
#    'the',
#    'blue',
#    'sheet']),
#  ('297285273_688e44c014.jpg',
#   ['three',
#    'children',
#    'are',
#    'playing',
#    'on',
#    'the',
#    'shoreline',
#    'with',
#    'a',
#    'ferry',
#    'docked',
#    'in',
#    'the',
#    'background']),
#  ('1459032057_97e73ed6ab.jpg',
#   ['this',
#    'girl',
#    'is',
#    'eating',
#    'a',
#    'piece',
#    'of',
#    'bread',
#    'in',
#    'her',
#    'striped',
#    'shirt']),
#  ('3472066410_065b4f99d3.jpg',
#   ['a',
#    'woman',
#    'with',
#    'long',
#    'hair',
#    'jumps',
#    'from',
#    'a',
#    'stone',
#    'bench',
#    'to',
#    'another']),
#  ('3148811252_2fa9490a04.jpg',
#   ['the',
#    'basketball',
#    'player',
#    'in',
#    'white',
#    'is',
#    'holding',
#    'an',
#    'orange',
#    'basketball']),
#  ('2759211664_d21393b668.jpg',
#   ['the',
#    'blonde',
#    'girl',
#    'is',
#    'watching',
#    'the',
#    'boy',
#    'run',
#    'barefoot',
#    'on',
#    'the',
#    'ground']),
#  ('3329169877_175cb16845.jpg',
#   ['someone',
#    'in',
#    'green',
#    'pants',
#    'is',
#    'on',
#    'a',
#    'white',
#    'snowboard',
#    'in',
#    'the',
#    'air']),
#  ('1818403842_553a2a392c.jpg',
#   ['two',
#    'black',
#    'dogs',
#    'are',
#    'diving',
#    'into',
#    'a',
#    'pool',
#    'to',
#    'get',
#    'a',
#    'dog',
#    'toy']),
#  ('3530087422_7eb2b2c289.jpg',
#   ['a',
#    'person',
#    'in',
#    'a',
#    'red',
#    'black',
#    'and',
#    'white',
#    'racing',
#    'suit',
#    'and',
#    'a',
#    'helmet',
#    'is',
#    'riding',
#    'a',
#    'skateboard']),
#  ('3674565156_14d3b41450.jpg',
#   ['a',
#    'woman',
#    'wearing',
#    'purple',
#    'looks',
#    'away',
#    'while',
#    'a',
#    'woman',
#    'in',
#    'orange',
#    'grins',
#    'at',
#    'the',
#    'camera']),
#  ('3480379024_545e8ec818.jpg',
#   ['two', 'motorcycle', 'racers', 'ride', 'along', 'a', 'racetrack']),
#  ('1277743944_f4e8c78403.jpg',
#   ['a',
#    'boy',
#    'dressed',
#    'in',
#    'khaki',
#    'shorts',
#    'and',
#    'a',
#    'red',
#    'shirt',
#    'runs',
#    'on',
#    'a',
#    'beach',
#    'with',
#    'green',
#    'white',
#    'and',
#    'blue',
#    'structures',
#    'and',
#    'a',
#    'half',
#    'moon',
#    'behind',
#    'him']),
#  ('717673249_ac998cfbe6.jpg', ['two', 'dogs', 'play', 'in', 'the', 'grass']),
#  ('2114126343_a0f74ff63b.jpg',
#   ['six', 'girls', 'hold', 'a', 'rope', 'in', 'the', 'ocean']),
#  ('3652572138_34d6b72999.jpg',
#   ['the',
#    'boy',
#    'in',
#    'the',
#    'purple',
#    'shirt',
#    'and',
#    'green',
#    'jacket',
#    'stands',
#    'in',
#    'the',
#    'crowd',
#    'whilst',
#    'raising',
#    'his',
#    'hands',
#    'in',
#    'the',
#    'air']),
#  ('389643437_9a9830a3ba.jpg',
#   ['two', 'children', 'taking', 'in', 'a', 'snack']),
#  ('146577645_91b570c0d0.jpg',
#   ['a', 'man', 'with', 'a', 'red', 'helmet', 'kayaking']),
#  ('96985174_31d4c6f06d.jpg', ['a', 'man', 'walks', 'near', 'mountains']),
#  ('2952141476_fc9a48a60a.jpg', ['a', 'man', 'floating', 'in', 'the', 'ocean']),
#  ('536828916_b763b82949.jpg',
#   ['a', 'red', 'haired', 'woman', 'looks', 'past', 'the', 'cameraman']),
#  ('2665461736_595c87f0a3.jpg',
#   ['the',
#    'adult',
#    'cooks',
#    'over',
#    'the',
#    'fire',
#    'as',
#    'the',
#    'child',
#    'looks',
#    'on']),
#  ('431018958_84b2beebff.jpg',
#   ['girl', 'pushing', 'boat', 'with', 'a', 'pole', 'in', 'the', 'water']),
#  ('3547600292_6f8aac7f2e.jpg',
#   ['a', 'black', 'and', 'orange', 'bird', 'in', 'the', 'grass']),
#  ('458004873_f084c47a88.jpg',
#   ['a',
#    'man',
#    'is',
#    'sitting',
#    'on',
#    'a',
#    'bench',
#    'facing',
#    'another',
#    'man',
#    'who',
#    'is',
#    'standing']),
#  ('3739833689_a0038545bd.jpg',
#   ['little',
#    'boy',
#    'puts',
#    'his',
#    'forehead',
#    'on',
#    'the',
#    'baseball',
#    'bat',
#    'and',
#    'spins',
#    'around',
#    'to',
#    'make',
#    'himself',
#    'dizzy']),
#  ('2509824208_247aca3ea3.jpg',
#   ['a',
#    'brown',
#    'dog',
#    'is',
#    'running',
#    'very',
#    'fast',
#    'with',
#    'his',
#    'tongue',
#    'out']),
#  ('3636055584_65a60426f8.jpg',
#   ['three',
#    'men',
#    'in',
#    'uniforms',
#    'are',
#    'playing',
#    'cricket',
#    'on',
#    'a',
#    'field']),
#  ('537758332_8beb9cf522.jpg',
#   ['two', 'children', 'are', 'on', 'a', 'giant', 'inflatable', 'slide']),
#  ('1417941060_2a0f7908bc.jpg',
#   ['a',
#    'boy',
#    'who',
#    'seems',
#    'ill',
#    'is',
#    'being',
#    'touched',
#    'in',
#    'the',
#    'face',
#    'by',
#    'a',
#    'toddler']),
#  ('856985136_649c0a3881.jpg',
#   ['a',
#    'young',
#    'woman',
#    'tries',
#    'to',
#    'stick',
#    'her',
#    'foot',
#    'in',
#    'a',
#    'fountain']),
#  ('2706430695_3b5667741c.jpg',
#   ['an',
#    'older',
#    'girl',
#    'and',
#    'a',
#    'younger',
#    'girl',
#    'playing',
#    'barefoot',
#    'in',
#    'a',
#    'puddle']),
#  ('3106791484_13e18c33d8.jpg',
#   ['boy', 'in', 'black', 'shirt', 'jumps', 'onto', 'bed', 'from', 'dresser']),
#  ('2214132302_80064fd79d.jpg',
#   ['a',
#    'woman',
#    'in',
#    'a',
#    'red',
#    'jacket',
#    'and',
#    'orange',
#    'glasses',
#    'is',
#    'jogging']),
#  ('2949497756_be8e58e6bd.jpg',
#   ['two', 'tan', 'dogs', 'smell', 'each', 'others', 'faces']),
#  ('3334953664_a669038795.jpg',
#   ['a',
#    'baseball',
#    'player',
#    'in',
#    'a',
#    'blue',
#    'uniform',
#    'has',
#    'just',
#    'released',
#    'the',
#    'baseball',
#    'on',
#    'the',
#    'sidelines']),
#  ('2876848241_63290edfb4.jpg',
#   ['a', 'person', 'is', 'riding', 'a', 'green', 'motorcycle']),
#  ('2385146732_d1c67c790e.jpg',
#   ['two',
#    'people',
#    'are',
#    'standing',
#    'next',
#    'to',
#    'a',
#    'waterway',
#    'canal']),
#  ('3601803640_5f3cb05acf.jpg', ['a', 'man', 'and', 'a', 'woman', 'kissing']),
#  ('3339747039_1a8455c210.jpg',
#   ['a',
#    'man',
#    'sits',
#    'on',
#    'the',
#    'edge',
#    'of',
#    'a',
#    'cliff',
#    'overlooking',
#    'a',
#    'deep',
#    'valley']),
#  ('3547368652_0d85c665d3.jpg',
#   ['the', 'boy', 'is', 'skateboarding', 'on', 'the', 'stairs']),
#  ('2281768510_9cc5728c55.jpg',
#   ['a',
#    'man',
#    'in',
#    'red',
#    'swimming',
#    'trunks',
#    'stands',
#    'in',
#    'the',
#    'snow',
#    'on',
#    'a',
#    'cliff',
#    'above',
#    'the',
#    'water']),
#  ('2676015068_690b0fb2cd.jpg',
#   ['the',
#    'man',
#    'with',
#    'the',
#    'white',
#    't',
#    'shirt',
#    'is',
#    'sitting',
#    'in',
#    'a',
#    'stream',
#    'looking',
#    'at',
#    'a',
#    'rock']),
#  ('368212336_bc19b0bb72.jpg',
#   ['a', 'man', 'looking', 'across', 'a', 'street']),
#  ('2391269207_d1d2615b1d.jpg',
#   ['a',
#    'white',
#    'dog',
#    'with',
#    'a',
#    'yellow',
#    'toy',
#    'in',
#    'his',
#    'mouth',
#    'runs',
#    'through',
#    'a',
#    'nature',
#    'trail',
#    'towards',
#    'the',
#    'camera']),
#  ('1056873310_49c665eb22.jpg',
#   ['a', 'brown', 'dog', 'is', 'running', 'after', 'the', 'black', 'dog']),
#  ('3516935867_78cf63c69c.jpg',
#   ['a',
#    'black',
#    'horse',
#    'and',
#    'its',
#    'rider',
#    'are',
#    'clearing',
#    'a',
#    '3',
#    'rung',
#    'high',
#    'jump',
#    'in',
#    'a',
#    'competition']),
#  ('3660826540_481d25fbb0.jpg',
#   ['a', 'boy', 'points', 'at', 'something', 'behind', 'the', 'camera']),
#  ('2827964381_408a310809.jpg',
#   ['two',
#    'dogs',
#    'wrestle',
#    'in',
#    'the',
#    'grass',
#    'with',
#    'a',
#    'chain',
#    'link',
#    'fence',
#    'in',
#    'the',
#    'background']),
#  ('2196284168_76417efbec.jpg',
#   ['a',
#    'baby',
#    'boy',
#    'sucks',
#    'on',
#    'the',
#    'sweater',
#    'arm',
#    'of',
#    'the',
#    'woman',
#    'holding',
#    'him']),
#  ('2305437797_e6c3460190.jpg',
#   ['a', 'dog', 'swimming', 'with', 'a', 'stick', 'in', 'its', 'mouth']),
#  ('3269895626_7b253c82ed.jpg',
#   ['a', 'man', 'on', 'a', 'dirt', 'bike', 'is', 'covered', 'in', 'mud']),
#  ('2687328779_b4356dab16.jpg',
#   ['a',
#    'dog',
#    'is',
#    'hosed',
#    'as',
#    'it',
#    'jumps',
#    'into',
#    'a',
#    'kiddie',
#    'pool']),
#  ('1131340021_83f46b150a.jpg',
#   ['little',
#    'boy',
#    'in',
#    'a',
#    'striped',
#    'shirt',
#    'and',
#    'brown',
#    'shorts',
#    'is',
#    'running']),
#  ('417966898_a04f9b5349.jpg',
#   ['two',
#    'girls',
#    'hanging',
#    'upside',
#    'down',
#    'on',
#    'a',
#    'park',
#    'structure']),
#  ('3573202338_f43dd22d28.jpg',
#   ['a',
#    'girl',
#    'does',
#    'a',
#    'side',
#    'bend',
#    'in',
#    'the',
#    'surf',
#    'another',
#    'girl',
#    'behind',
#    'her',
#    'the',
#    'sun',
#    'setting']),
#  ('3023178539_836b50cd43.jpg',
#   ['two', 'boys', 'are', 'running', 'around', 'a', 'field']),
#  ('2308108566_2cba6bca53.jpg',
#   ['dirt', 'bike', 'rider', 'riding', 'down', 'the', 'slope']),
#  ('2384626662_67cdd87694.jpg', ['two', 'children', 'on', 'the', 'beach']),
#  ('2755952680_68a0a1fa42.jpg',
#   ['the', 'trick', 'bicyclist', 'gets', 'airborne', 'off', 'the', 'ramp']),
#  ('2425262733_afe0718276.jpg',
#   ['man',
#    'with',
#    'jeans',
#    'and',
#    'a',
#    'hooding',
#    'doing',
#    'skateboarding',
#    'tricks']),
#  ('3384528359_e920154177.jpg', ['bird', 'spreads', 'wings', 'over', 'water']),
#  ('3286017638_c688c83e3d.jpg',
#   ['a',
#    'man',
#    'helps',
#    'up',
#    'a',
#    'woman',
#    'who',
#    'has',
#    'fallen',
#    'after',
#    'kicking',
#    'a',
#    'soccer',
#    'ball']),
#  ('2766926202_4201bf2bf9.jpg',
#   ['two', 'men', 'play', 'with', 'fireworks', 'on', 'the', 'beach']),
#  ('241347243_c751557497.jpg',
#   ['oklahoma', 'sooner', 'football', 'players', 'on', 'the', 'field']),
#  ('537758332_8beb9cf522.jpg',
#   ['two', 'little', 'girls', 'slide', 'down', 'an', 'inflated', 'slide']),
#  ('2369840118_a1c4240ab7.jpg',
#   ['a', 'boy', 'holds', 'a', 'goat', 'in', 'his', 'arms']),
#  ('3407357681_5aeaab5b59.jpg',
#   ['a',
#    'dog',
#    'is',
#    'running',
#    'in',
#    'a',
#    'large',
#    'body',
#    'of',
#    'water',
#    'causing',
#    'it',
#    'to',
#    'splash']),
#  ('3462165890_c13ce13eff.jpg',
#   ['a',
#    'girl',
#    'with',
#    'a',
#    'white',
#    'backpack',
#    'is',
#    'standing',
#    'and',
#    'smaller',
#    'children',
#    'are',
#    'sitting',
#    'in',
#    'a',
#    'row',
#    'on',
#    'the',
#    'ground']),
#  ('300539993_eede2d6695.jpg',
#   ['a', 'black', 'and', 'brown', 'dog', 'chewing', 'on', 'a', 'stick']),
#  ('2662570182_350baa020f.jpg',
#   ['two',
#    'small',
#    'children',
#    'play',
#    'with',
#    'a',
#    'toy',
#    'riding',
#    'car',
#    'in',
#    'the',
#    'street',
#    'with',
#    'a',
#    'grown',
#    'up']),
#  ('2714699748_c9270dd5aa.jpg', ['two', 'dogs', 'wrestle']),
#  ('3454355269_6185e29f95.jpg',
#   ['man',
#    'in',
#    'safety',
#    'gear',
#    'riding',
#    'a',
#    'bike',
#    'on',
#    'a',
#    'rocky',
#    'trail']),
#  ('3532761259_14026c1e96.jpg',
#   ['two', 'women', 'wearing', 'red', 'are', 'smiling', 'at', 'the', 'camera']),
#  ('3066429707_842e50b8f7.jpg',
#   ['blond', 'girl', 'in', 'blue', 'clothes', 'playing', 'soccer']),
#  ('2064417101_3b9d817f4a.jpg',
#   ['three', 'dogs', 'run', 'across', 'the', 'track']),
#  ('3571675421_7e07ac07c5.jpg',
#   ['a', 'dog', 'running', 'through', 'the', 'water']),
#  ('3546474710_903c3c9fd3.jpg',
#   ['an',
#    'old',
#    'bald',
#    'man',
#    'in',
#    'the',
#    'spotlight',
#    'playing',
#    'the',
#    'guitar']),
#  ('2576878141_87f25a10f0.jpg',
#   ['a',
#    'small',
#    'child',
#    'wearing',
#    'light',
#    'blue',
#    'overalls',
#    'sits',
#    'on',
#    'a',
#    'red',
#    'slide']),
#  ('1089181217_ee1167f7af.jpg',
#   ['a', 'brown', 'dog', 'running', 'next', 'to', 'grass']),
#  ('241031670_e60f59b8e4.jpg',
#   ['the',
#    'three',
#    'children',
#    'are',
#    'holding',
#    'umbrellas',
#    'and',
#    'watching',
#    'the',
#    'ceremony',
#    'in',
#    'the',
#    'rain']),
#  ('3580082200_ea10bf2f68.jpg',
#   ['a',
#    'man',
#    'is',
#    'interacting',
#    'with',
#    'a',
#    'dog',
#    'that',
#    'is',
#    'running',
#    'past',
#    'him']),
#  ('1859941832_7faf6e5fa9.jpg',
#   ['a', 'pitbull', 'jumps', 'to', 'catch', 'a', 'flying', 'disc']),
#  ('1335617803_4fbc03dab0.jpg',
#   ['two', 'boys', 'in', 'blue', 'shirts', 'wearing', 'backpacks']),
#  ('1352398363_9cc8ffcce9.jpg',
#   ['a', 'boy', 'is', 'covered', 'with', 'marker']),
#  ('2873252292_ebf23f5f10.jpg',
#   ['a',
#    'mountain',
#    'biker',
#    'rides',
#    'up',
#    'a',
#    'hill',
#    'on',
#    'a',
#    'red',
#    'bicycle']),
#  ('530888330_a18343e38d.jpg',
#   ['a', 'shadowy', 'male', 'looking', 'at', 'the', 'far', 'away', 'hills']),
#  ('927420680_6cba7c040a.jpg',
#   ['the', 'man', 'walks', 'among', 'the', 'large', 'trees']),
#  ('3244734844_c318c29c23.jpg',
#   ['a',
#    'boy',
#    'wearing',
#    'a',
#    'blue',
#    'parka',
#    'green',
#    'pants',
#    'and',
#    'white',
#    'shoes',
#    'is',
#    'leaping',
#    'in',
#    'a',
#    'ramp']),
#  ('392976422_c8d0514bc3.jpg', ['a', 'boy', 'scales', 'the', 'wall']),
#  ('3096163135_584901a5ae.jpg',
#   ['a',
#    'person',
#    'wearing',
#    'a',
#    'red',
#    'hat',
#    'shaped',
#    'like',
#    'hands',
#    'sits',
#    'in',
#    'a',
#    'crowd']),
#  ('3053916979_848d32261b.jpg',
#   ['a',
#    'man',
#    'in',
#    'a',
#    'black',
#    'shirt',
#    'wanders',
#    'around',
#    'amongst',
#    'fencing',
#    'players']),
#  ('2925242998_9e0db9b4a2.jpg',
#   ['a',
#    'woman',
#    'hiker',
#    'stopped',
#    'at',
#    'the',
#    'top',
#    'of',
#    'a',
#    'mountain',
#    'with',
#    'a',
#    'beautiful',
#    'view']),
#  ('366713533_bd6d48cf02.jpg',
#   ['the', 'people', 'are', 'standing', 'in', 'front', 'of', 'a', 'building']),
#  ('2095078658_c14ba89bc2.jpg',
#   ['the',
#    'german',
#    'shepherd',
#    'is',
#    'running',
#    'through',
#    'the',
#    'white',
#    'snow']),
#  ('3174713468_e22fa7779e.jpg',
#   ['a',
#    'dog',
#    'jumps',
#    'up',
#    'to',
#    'take',
#    'something',
#    'from',
#    'a',
#    'woman',
#    's',
#    'hand']),
#  ('3304511635_113beaf458.jpg',
#   ['a',
#    'woman',
#    'in',
#    'an',
#    'orange',
#    'dress',
#    'is',
#    'dancing',
#    'with',
#    'a',
#    'man',
#    'in',
#    'a',
#    'black',
#    'suit']),
#  ('3234719720_5bb2fc5ffa.jpg',
#   ['a',
# ...
#    'boy',
#    'in',
#    'a',
#    'yellow',
#    'shirt',
#    'is',
#    'walking',
#    'behind',
#    'two',
#    'people',
#    'and',
#    'also',
#    'is',
#    'passing',
#    'by',
#    'a',
#    'statue']),
#  ('3403797144_53e49412ec.jpg', ['a', 'surfer', 'on', 'a', 'wave']),
#  ('486720042_b785e7f88c.jpg',
#   ['two', 'dogs', 'play', 'in', 'a', 'sandy', 'field']),
#  ('408748500_e8dc8c0c4f.jpg',
#   ['the',
#    'girl',
#    'in',
#    'the',
#    'red',
#    'jacket',
#    'is',
#    'next',
#    'to',
#    'a',
#    'picture',
#    'of',
#    'a',
#    'funny',
#    'face']),
#  ('2701895972_8605c4e038.jpg', ['a', 'band', 'performs', 'onstage']),
#  ('2220175999_081aa9cce8.jpg',
#   ['two', 'dogs', 'are', 'wading', 'in', 'a', 'river']),
#  ('3608400551_d6f7965308.jpg',
#   ['a',
#    'tattooed',
#    'man',
#    'with',
#    'a',
#    'white',
#    'dog',
#    'jumping',
#    'up',
#    'for',
#    'a',
#    'stick']),
#  ('2430860418_fd0726f414.jpg',
#   ['the',
#    'white',
#    'dog',
#    'with',
#    'pointed',
#    'ears',
#    'is',
#    'running',
#    'on',
#    'the',
#    'dirt']),
#  ('3744832122_2f4febdff6.jpg',
#   ['a', 'young', 'person', 'pitches', 'in', 'a', 'baseball', 'game']),
#  ('2862509442_4f5dc96dca.jpg',
#   ['the', 'drag', 'racers', 'take', 'off', 'the', 'starting', 'line']),
#  ('3636632926_09f39f2629.jpg', ['children', 'walk', 'in', 'the', 'city']),
#  ('2452238877_2340609c6e.jpg',
#   ['a',
#    'golden',
#    'retriever',
#    'is',
#    'jumping',
#    'off',
#    'a',
#    'wooden',
#    'porch']),
#  ('2063277300_f7ff476914.jpg',
#   ['three',
#    'young',
#    'kids',
#    'are',
#    'all',
#    'tangled',
#    'up',
#    'together',
#    'and',
#    'playing',
#    'on',
#    'a',
#    'big',
#    'rug']),
#  ('2940594396_20c40947b0.jpg',
#   ['the',
#    'handicapped',
#    'biker',
#    'uses',
#    'his',
#    'arms',
#    'to',
#    'move',
#    'his',
#    'yellow',
#    'sports',
#    'bike']),
#  ('2054308369_f9c6ec7815.jpg',
#   ['a', 'little', 'girl', 'is', 'petting', 'a', 'golden', 'dog']),
#  ('2769605231_dae8b30201.jpg',
#   ['a', 'black', 'dog', 'is', 'in', 'a', 'dog', 'race']),
#  ('2662537919_18a29fca8a.jpg',
#   ['a', 'man', 'rocks', 'out', 'onstage', 'with', 'his', 'guitar']),
#  ('2546667441_bbe87a6285.jpg',
#   ['a',
#    'black',
#    'dog',
#    'is',
#    'walking',
#    'along',
#    'the',
#    'grass',
#    'sniffing',
#    'at',
#    'the',
#    'ground']),
#  ('2800758232_d7fa598065.jpg',
#   ['a', 'man', 'and', 'a', 'woman', 'are', 'staring', 'into', 'the', 'ocean']),
#  ('2282043629_91b7831352.jpg',
#   ['a',
#    'man',
#    'and',
#    'a',
#    'woman',
#    'pose',
#    'in',
#    'the',
#    'snow',
#    'with',
#    'four',
#    'children']),
#  ('197924859_f6e39a7dfa.jpg',
#   ['a',
#    'person',
#    'bathes',
#    'in',
#    'a',
#    'homemade',
#    'shower',
#    'with',
#    'a',
#    'green',
#    'watering',
#    'can']),
#  ('2251447809_2de73afcdf.jpg',
#   ['a', 'man', 'walks', 'on', 'the', 'icy', 'sidewalk']),
#  ('3465791729_5bf9bd8635.jpg',
#   ['there',
#    'are',
#    '2',
#    'men',
#    'dressed',
#    'in',
#    'stripes',
#    'sitting',
#    'under',
#    'a',
#    'green',
#    'umbrella']),
#  ('3497238310_2abde3965d.jpg',
#   ['a',
#    'group',
#    'of',
#    'men',
#    'stand',
#    'in',
#    'a',
#    'gymnasium',
#    'with',
#    'a',
#    'basketball']),
#  ('3253060519_55d98c208f.jpg',
#   ['an', 'anciet', 'city', 'with', 'people', 'walking', 'the', 'streets']),
#  ('3596959859_a7cb1e194b.jpg',
#   ['a',
#    'team',
#    'of',
#    'workers',
#    'breaks',
#    'up',
#    'stone',
#    'on',
#    'the',
#    'ground']),
#  ('3367851138_757d6bd2ef.jpg',
#   ['a', 'red', 'tugboat', 'is', 'about', 'to', 'dock', 'at', 'a', 'port']),
#  ('3280173193_98c2d6a223.jpg',
#   ['two',
#    'women',
#    'wrestle',
#    'at',
#    'the',
#    'beach',
#    'next',
#    'to',
#    'a',
#    'city']),
#  ('556568556_bc5124dc8e.jpg',
#   ['a',
#    'little',
#    'kid',
#    'plays',
#    'on',
#    'the',
#    'swing',
#    'at',
#    'the',
#    'playground']),
#  ('1084104085_3b06223afe.jpg',
#   ['a',
#    'woman',
#    'in',
#    'blue',
#    'shorts',
#    'and',
#    'a',
#    'white',
#    'shirt',
#    'is',
#    'indoor',
#    'rock',
#    'climbing']),
#  ('927420680_6cba7c040a.jpg',
#   ['someone',
#    'in',
#    'a',
#    'light',
#    'shirt',
#    'is',
#    'walking',
#    'past',
#    'several',
#    'large',
#    'trees',
#    'overlooking',
#    'a',
#    'city']),
#  ('2846785268_904c5fcf9f.jpg',
#   ['a',
#    'person',
#    'wearing',
#    'rollerblades',
#    'jumps',
#    'over',
#    'a',
#    'yellow',
#    'gate']),
#  ('2399114095_c3196ff456.jpg',
#   ['two',
#    'dogs',
#    'with',
#    'the',
#    'same',
#    'coloring',
#    'look',
#    'like',
#    'they',
#    'are',
#    'going',
#    'to',
#    'bite',
#    'each',
#    'other',
#    'in',
#    'the',
#    'face']),
#  ('3556390715_65c6d1e88b.jpg',
#   ['the', 'small', 'dogs', 'runs', 'in', 'the', 'yard']),
#  ('3457455611_94ee93929f.jpg',
#   ['little',
#    'boy',
#    'in',
#    'green',
#    'tube',
#    'smilling',
#    'with',
#    'his',
#    'hair',
#    'sticking',
#    'up',
#    'he',
#    'has',
#    'on',
#    'a',
#    'black',
#    'and',
#    'blue',
#    'striped',
#    'shirt',
#    'and',
#    'tennis',
#    'shoes']),
#  ('861795382_5145ad433d.jpg',
#   ['a',
#    'boy',
#    'in',
#    'a',
#    'blue',
#    'shirt',
#    'and',
#    'shorts',
#    'jumping',
#    'a',
#    'bike',
#    'with',
#    'a',
#    'ramp']),
#  ('1563731247_7f21d8bec0.jpg',
#   ['little',
#    'girl',
#    'buried',
#    'in',
#    'hay',
#    'throwing',
#    'hay',
#    'around',
#    'at',
#    'a',
#    'lady']),
#  ('2751466788_4fab701cc3.jpg',
#   ['a',
#    'police',
#    'officer',
#    'directs',
#    'traffic',
#    'on',
#    'a',
#    'city',
#    'street']),
#  ('143688205_630813a466.jpg',
#   ['a',
#    'man',
#    'using',
#    'a',
#    'pink',
#    'rope',
#    'to',
#    'climb',
#    'down',
#    'a',
#    'cliff']),
#  ('3726700898_c50494b8bd.jpg',
#   ['a',
#    'young',
#    'man',
#    'shows',
#    'off',
#    'a',
#    'knife',
#    'trick',
#    'to',
#    'another']),
#  ('2935703360_4f794f7f09.jpg',
#   ['a', 'little', 'dog', 'running', 'between', 'yellow', 'poles']),
#  ('2466093839_33bbc8cbd9.jpg', ['two', 'young', 'kids', 'play', 'and', 'run']),
#  ('2616284322_b13e7c344e.jpg',
#   ['the', 'dogs', 'run', 'a', 'race', 'at', 'the', 'track']),
#  ('2776029171_5abdd5a22f.jpg',
#   ['a',
#    'little',
#    'boy',
#    'is',
#    'running',
#    'on',
#    'the',
#    'round',
#    'playing',
#    'with',
#    'a',
#    'little',
#    'girl']),
#  ('3503471307_464a8f588c.jpg',
#   ['the', 'boy', 'does', 'a', 'jumps', 'his', 'bike', 'into', 'the', 'air']),
#  ('3239480519_22540b5016.jpg',
#   ['a',
#    'playful',
#    'dog',
#    'running',
#    'across',
#    'the',
#    'snowy',
#    'field',
#    'with',
#    'a',
#    'stick',
#    'in',
#    'its',
#    'mouth']),
#  ('2934325103_e9b8d7430f.jpg',
#   ['a', 'biker', 'rides', 'on', 'a', 'dirt', 'road']),
#  ('2126950128_74a4882658.jpg',
#   ['a',
#    'woman',
#    'with',
#    'a',
#    'black',
#    'bag',
#    'is',
#    'smoking',
#    'a',
#    'cigarette']),
#  ('2812590023_50182bc417.jpg',
#   ['smoke',
#    'is',
#    'spewing',
#    'out',
#    'of',
#    'the',
#    'back',
#    'of',
#    'a',
#    'red',
#    'race',
#    'car',
#    'on',
#    'a',
#    'racetrack']),
#  ('3561130207_d1ed166daa.jpg',
#   ['a',
#    'large',
#    'group',
#    'of',
#    'people',
#    'are',
#    'watching',
#    'something',
#    'screaming',
#    'and',
#    'taking',
#    'pictures']),
#  ('662606040_8cc8cd9f1b.jpg',
#   ['a',
#    'small',
#    'dog',
#    'runs',
#    'after',
#    'a',
#    'red',
#    'ball',
#    'though',
#    'a',
#    'leafy',
#    'outdoor',
#    'area']),
#  ('2956895529_ec6275060e.jpg',
#   ['a', 'bicyclist', 'jumping', 'a', 'trick', 'on', 'a', 'bike']),
#  ('475042270_719ebe6c48.jpg',
#   ['a',
#    'golden',
#    'retriever',
#    'is',
#    'playing',
#    'with',
#    'a',
#    'smaller',
#    'black',
#    'and',
#    'brown',
#    'dog',
#    'in',
#    'a',
#    'pink',
#    'collar']),
#  ('2600170955_bf30c5d5c0.jpg',
#   ['an',
#    'enthusiastic',
#    'boy',
#    'pushes',
#    'a',
#    'shopping',
#    'cart',
#    'containing',
#    'a',
#    'smiling',
#    'boy']),
#  ('426191845_1e979e9345.jpg',
#   ['a', 'dog', 'is', 'running', 'in', 'the', 'dirt', 'and', 'snow']),
#  ('3304511635_113beaf458.jpg',
#   ['a',
#    'woman',
#    'in',
#    'a',
#    'lavish',
#    'orange',
#    'dress',
#    'dances',
#    'with',
#    'a',
#    'man',
#    'in',
#    'all',
#    'black',
#    'clothing']),
#  ('3090600019_8808fe7a9d.jpg',
#   ['a',
#    'man',
#    'dresses',
#    'as',
#    'a',
#    'prisoner',
#    'and',
#    'a',
#    'woman',
#    'dressed',
#    'as',
#    'a',
#    'cop',
#    'on',
#    'a',
#    'sidewalk']),
#  ('684375286_09cc1aa778.jpg', ['two', 'dogs', 'play', 'tug', 'of', 'war']),
#  ('3424927725_c4d1fcfac3.jpg',
#   ['a',
#    'person',
#    'in',
#    'a',
#    'yellow',
#    'raincoat',
#    'seating',
#    'on',
#    'a',
#    'cliff']),
#  ('3357194782_c261bb6cbf.jpg',
#   ['some', 'people', 'riding', 'an', 'old', 'bus']),
#  ('3244734844_c318c29c23.jpg',
#   ['a',
#    'man',
#    'wearing',
#    'a',
#    'blue',
#    'jacket',
#    'jumping',
#    'from',
#    'one',
#    'concrete',
#    'wall',
#    'to',
#    'the',
#    'other']),
#  ('1858963639_4588cd4be9.jpg',
#   ['a',
#    'woman',
#    'with',
#    'a',
#    'helmet',
#    'and',
#    'climbing',
#    'rope',
#    'smiles',
#    'at',
#    'the',
#    'camera']),
#  ('397982550_cf9f5cdb74.jpg',
#   ['a',
#    'man',
#    'is',
#    'standing',
#    'on',
#    'an',
#    'icy',
#    'street',
#    'with',
#    'a',
#    'building',
#    'beside',
#    'him']),
#  ('241347700_ef2451d256.jpg',
#   ['a',
#    'man',
#    'dressed',
#    'in',
#    'red',
#    'takes',
#    'a',
#    'picture',
#    'of',
#    'a',
#    'sporting',
#    'event']),
#  ('3684680947_f1c460242f.jpg',
#   ['a',
#    'boy',
#    'in',
#    'a',
#    'red',
#    'shirt',
#    'walks',
#    'down',
#    'the',
#    'street',
#    'through',
#    'heavy',
#    'rain']),
#  ('241109594_3cb90fe2a3.jpg',
#   ['a', 'dog', 'swims', 'retrieving', 'a', 'stick']),
#  ('1803631090_05e07cc159.jpg',
#   ['the',
#    'woman',
#    'wearing',
#    'a',
#    'fire',
#    'department',
#    'uniform',
#    'is',
#    'talking',
#    'to',
#    'people']),
#  ('3682428916_69ce66d375.jpg', ['a', 'person', 'in', 'an', 'airplane']),
#  ('246901891_4c4ea49c3a.jpg', ['a', 'man', 'steps', 'onto', 'a', 'sidewalk']),
#  ('2712352554_1cafd32812.jpg',
#   ['a', 'guy', 'with', 'no', 'shirt', 'on', 'is', 'skateboarding']),
#  ('260231029_966e2f1727.jpg',
#   ['a',
#    'black',
#    'dog',
#    'plays',
#    'with',
#    'a',
#    'brown',
#    'dog',
#    'on',
#    'the',
#    'sand']),
#  ('3532192208_64b069d05d.jpg',
#   ['man', 'with', 'grey', 'shirt', 'with', 'a', 'white', 'name', 'badge']),
#  ('2839932205_3c9c27cd99.jpg',
#   ['a',
#    'person',
#    'is',
#    'climbing',
#    'to',
#    'the',
#    'top',
#    'of',
#    'a',
#    'rock',
#    'cliff']),
#  ('2169951750_495820a215.jpg',
#   ['a', 'brown', 'dog', 'is', 'running', 'across', 'the', 'snowy', 'ground']),
#  ('470903027_489cc507de.jpg',
#   ['a',
#    'person',
#    'wearing',
#    'a',
#    'hat',
#    'sits',
#    'on',
#    'the',
#    'grass',
#    'with',
#    'a',
#    'mountain',
#    'behind',
#    'him']),
#  ('2242863004_3a9f82a31f.jpg',
#   ['a', 'dog', 'attempting', 'to', 'chew', 'on', 'a', 'red', 'ball']),
#  ('3640348910_fcd627ec66.jpg',
#   ['a',
#    'skateboarder',
#    'does',
#    'an',
#    'ollie',
#    'off',
#    'a',
#    'black',
#    'ramp',
#    'near',
#    'a',
#    'colorfully',
#    'painted',
#    'building']),
#  ('2609847254_0ec40c1cce.jpg',
#   ['a',
#    'girl',
#    'is',
#    'smiling',
#    'at',
#    'the',
#    'camera',
#    'with',
#    'a',
#    'crowd',
#    'of',
#    'people',
#    'behind',
#    'her']),
#  ('2891924845_92f69b0f18.jpg',
#   ['a', 'man', 'and', 'a', 'woman', 'in', 'front', 'of', 'a', 'train']),
#  ('3047264032_14393ecea8.jpg',
#   ['a', 'yellow', 'shirted', 'man', 'wearing', 'a', 'golden', 'sun', 'mask']),
#  ('2982881046_45765ced2c.jpg',
#   ['a', 'person', 'jumping', 'with', 'a', 'bicycle', 'over', 'a', 'ramp']),
#  ('3515358125_9e1d796244.jpg',
#   ['a',
#    'large',
#    'brown',
#    'dog',
#    'runs',
#    'after',
#    'a',
#    'tennis',
#    'ball',
#    'in',
#    'a',
#    'field']),
#  ('1463638541_c02cfa04dc.jpg',
#   ['a',
#    'girl',
#    'is',
#    'climbing',
#    'up',
#    'a',
#    'rope',
#    'ladder',
#    'with',
#    'a',
#    'harness']),
#  ('3308018795_68a97a425c.jpg',
#   ['many',
#    'people',
#    'are',
#    'in',
#    'the',
#    'bicycle',
#    'racing',
#    'including',
#    'one',
#    'man',
#    'in',
#    'a',
#    'three',
#    'wheeled',
#    'bike']),
#  ('3394586927_eae7732b64.jpg',
#   ['the',
#    'man',
#    'in',
#    'the',
#    'black',
#    'shirt',
#    'is',
#    'skateboarding',
#    'on',
#    'the',
#    'front',
#    'steps',
#    'of',
#    'the',
#    'building']),
#  ('391020801_aaaae1e42b.jpg',
#   ['a',
#    'old',
#    'man',
#    'in',
#    'a',
#    'wall',
#    'mart',
#    'unifrom',
#    'holds',
#    'his',
#    'arms',
#    'out',
#    'to',
#    'the',
#    'camera']),
#  ('399212516_d68046b277.jpg',
#   ['a',
#    'veteran',
#    'in',
#    'a',
#    'brown',
#    'uniform',
#    'at',
#    'a',
#    'parade',
#    'with',
#    'children',
#    'and',
#    'american',
#    'flags']),
#  ('539493431_744eb1abaa.jpg', ['man', 'throws', 'flames', 'outside']),
#  ('3614881872_ccf9739b0e.jpg',
#   ['a',
#    'snowboarder',
#    'jumps',
#    'off',
#    'an',
#    'old',
#    'snow',
#    'covered',
#    'building']),
#  ('2656749876_e32495bd8c.jpg',
#   ['priest',
#    'walking',
#    'with',
#    'blue',
#    'bag',
#    'while',
#    'talking',
#    'on',
#    'cellphone']),
#  ('1620397000_3883e3ecd3.jpg',
#   ['a',
#    'black',
#    'and',
#    'white',
#    'spotted',
#    'dog',
#    'jumps',
#    'over',
#    'a',
#    'stream']),
#  ('2999162229_80d17099b6.jpg',
#   ['a', 'girl', 'in', 'orange', 'lights', 'a', 'candle']),
#  ('1923476156_e20976b32d.jpg',
#   ['a',
#    'white',
#    'dog',
#    'being',
#    'led',
#    'by',
#    'a',
#    'person',
#    'on',
#    'a',
#    'bicycle']),
#  ('3376435746_1593d9b243.jpg',
#   ['fisherman',
#    'motors',
#    'ahead',
#    'in',
#    'his',
#    'boat',
#    'facing',
#    'the',
#    'sun']),
#  ('2473737724_355599a263.jpg', ['two', 'girls', 'karate', 'fighting']),
#  ('2986671935_0c60bbb3fa.jpg',
#   ['men', 'in', 'a', 'cluster', 'during', 'a', 'bike', 'race']),
#  ('2955099064_1815b00825.jpg',
#   ['three', 'men', 'wrestle', 'for', 'a', 'soccer', 'ball']),
#  ('2665461736_595c87f0a3.jpg',
#   ['a',
#    'man',
#    'in',
#    'a',
#    'yellow',
#    'coat',
#    'tends',
#    'a',
#    'fire',
#    'a',
#    'boy',
#    'in',
#    'a',
#    'parka',
#    'watches']),
#  ('2830755303_2b5444ab4c.jpg',
#   ['a',
#    'small',
#    'child',
#    'is',
#    'running',
#    'on',
#    'the',
#    'shore',
#    'of',
#    'the',
#    'beach',
#    'surrounded',
#    'by',
#    'birds']),
#  ('3562302012_0cbcd01ff9.jpg',
#   ['little',
#    'boy',
#    'wearing',
#    'jeans',
#    'is',
#    'playing',
#    'on',
#    'industrial',
#    'equipment']),
#  ('380041023_0dfd712ef1.jpg', ['a', 'brown', 'dog', 'is', 'running']),
#  ('2465218087_fca77998c6.jpg',
#   ['a',
#    'man',
#    'holding',
#    'a',
#    'paddle',
#    'is',
#    'standing',
#    'in',
#    'front',
#    'of',
#    'a',
#    'yellow',
#    'kayak']),
#  ('2049646140_d0de01e3c4.jpg',
#   ['gymnast', 'does', 'a', 'flip', 'on', 'blue', 'flooring']),
#  ('1685990174_09c4fb7df8.jpg',
#   ['a', 'bunch', 'of', 'kids', 'run', 'on', 'a', 'school', 'play', 'field']),
#  ('2203286182_b453e9d176.jpg',
#   ['a', 'black', 'dog', 'is', 'chasing', 'after', 'a', 'red', 'frisbee']),
#  ('2195887578_3ba2f29b48.jpg',
#   ['two', 'older', 'men', 'in', 'front', 'of', 'a', 'bus']),
#  ('2671602981_4edde92658.jpg',
#   ['the',
#    'girl',
#    'in',
#    'the',
#    'bathing',
#    'suit',
#    'is',
#    'poised',
#    'in',
#    'midair',
#    'next',
#    'to',
#    'the',
#    'blue',
#    'water']),
#  ('2587017287_888c811b5a.jpg',
#   ['a', 'brown', 'dog', 'walks', 'through', 'natural', 'water']),
#  ('2521062020_f8b983e4b2.jpg',
#   ['a',
#    'young',
#    'boy',
#    'is',
#    'getting',
#    'harnessed',
#    'and',
#    'ready',
#    'to',
#    'climb',
#    'a',
#    'manmade',
#    'rock',
#    'wall']),
#  ('3090386315_87ed417814.jpg',
#   ['a', 'dog', 'runs', 'across', 'the', 'leaf', 'covered', 'ground']),
#  ('2548777800_d7b9cf1c2b.jpg',
#   ['a',
#    'boy',
#    'celebrating',
#    'with',
#    'paint',
#    'on',
#    'his',
#    'face',
#    'and',
#    'clothing']),
#  ('2353119813_685bace18e.jpg',
#   ['a',
#    'dog',
#    'is',
#    'jumping',
#    'playing',
#    'with',
#    'a',
#    'ball',
#    'that',
#    'has',
#    'broken']),
#  ('2256138896_3e24b0b28d.jpg',
#   ['a', 'rock', 'climber', 'with', 'a', 'white', 'helmet', 'is', 'repelling']),
#  ('3072782873_3278f3b3a7.jpg',
#   ['couple', 'kissing', 'in', 'the', 'middle', 'of', 'a', 'street']),
#  ('3534952095_975cca0056.jpg',
#   ['a', 'lady', 'riding', 'a', 'mini', 'motorcycle']),
#  ('2908512223_7e27631ed4.jpg',
#   ['a',
#    'little',
#    'girl',
#    'in',
#    'a',
#    'yellow',
#    'dress',
#    'and',
#    'pink',
#    'boots',
#    'running',
#    'down',
#    'the',
#    'street']),
#  ...]

# %% [markdown]
# ## Encoder

# %%
#export

# this is the encoder rnn. for ecodings use a resnet
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, n_features, n_out_features):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        
        self.embeddings = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.fc = nn.Linear(self.hidden_size + n_features, n_out_features)
        
    def forward(self, img, input, hidden):
        embedded = self.embeddings(input)
        output = embedded
        
        # format img to feed into fc layer
        n = sent.size(0)
        img = torch.from_numpy(np.tile(img, (n, 1)))
        img = torch.unsqueeze(img, 1)
        
        # feed into fc layer
        output = torch.cat((img, output), dim=-1)
        output = F.relu(self.fc(output))
        
        output, hidden = self.gru(output, hidden)
        return output, hidden
    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
hidden_size = 512
input_size = lang.n_words

encoder = EncoderRNN(input_size, hidden_size, n_features=512, n_out_features=512)
encoder
# Out:
# EncoderRNN(
#   (embeddings): Embedding(7376, 512)
#   (gru): GRU(512, 512)
#   (fc): Linear(in_features=1024, out_features=512, bias=True)
# )

# %%
hidden = encoder.initHidden()
output, hidden = encoder(img, sent, hidden)

# %%
output.shape, hidden.shape
# Out:
# (torch.Size([14, 1, 512]), torch.Size([1, 1, 512]))

# %% [markdown]
# ## Decoder

# %%
#export
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        
        self.embeddings = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
        
    def forward(self, input, hidden):
        output = self.embeddings(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.out(output)
        print(output.shape)
        output = self.softmax(output)
        print(output.shape)
        return output, hidden
    
    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
decoder = DecoderRNN(hidden_size, lang.n_words)
decoder
# Out:
# DecoderRNN(
#   (embeddings): Embedding(7376, 512)
#   (gru): GRU(512, 512)
#   (out): Linear(in_features=512, out_features=7376, bias=True)
#   (softmax): LogSoftmax()
# )

# %%
target_len = sent.size(0)

# %%
decoder_input = torch.tensor([[SOS_token]], device=device)

output, hidden = decoder(decoder_input, hidden)
output.shape, hidden.shape
# Out:
# torch.Size([1, 1, 7376])
# torch.Size([1, 1, 7376])
# (torch.Size([1, 1, 7376]), torch.Size([1, 1, 512]))

# %%
_, output = output.topk(1)
output.shape, decoder_input.shape
# Out:
# (torch.Size([1, 1, 1]), torch.Size([1, 1]))

# %%
decoder(output, hidden)
# Out:
# torch.Size([1, 1, 7376])
# torch.Size([1, 1, 7376])
# (tensor([[[0., 0., 0.,  ..., 0., 0., 0.]]], grad_fn=<LogSoftmaxBackward>),
#  tensor([[[-7.3828e-02,  3.5051e-01,  9.4528e-03,  1.2378e-01, -1.9783e-02,
#             2.1174e-02, -1.9180e-01, -2.2130e-03, -1.1323e-01,  2.3941e-01,
#             2.8382e-01,  1.4417e-01,  1.7306e-01, -2.1401e-01,  6.6446e-02,
#             2.5142e-01, -3.1836e-01,  5.5944e-01,  2.2823e-02, -3.2213e-01,
#            -2.5474e-01, -3.2703e-01, -2.9756e-02,  3.2013e-01, -9.9566e-02,
#            -5.9875e-03,  1.3243e-01,  4.4257e-01,  2.5005e-01, -1.1452e-01,
#            -2.7099e-01, -4.1905e-03,  1.1201e-01,  1.9497e-02,  6.8550e-02,
#            -1.2297e-01, -2.1383e-01, -9.4193e-02, -2.2402e-01,  1.7501e-01,
#            -1.7964e-01, -9.2075e-02, -1.3106e-01, -4.0252e-01, -8.9865e-02,
#             2.5837e-01,  3.9030e-01,  4.5934e-02,  1.5891e-01, -2.9085e-01,
#             2.6306e-02,  8.6565e-02,  7.8658e-02,  1.3097e-01, -1.0183e-02,
#            -1.7066e-01,  4.7572e-02,  1.1945e-01,  3.8104e-02, -3.8584e-01,
#            -3.1101e-01,  6.7174e-03,  2.4845e-01,  2.5932e-01, -9.4498e-02,
#            -5.8094e-02, -6.9713e-02, -1.7450e-01, -2.9773e-01,  7.7111e-02,
#             1.5675e-01,  3.3654e-01,  3.4886e-01, -3.7574e-01, -3.0737e-01,
#            -1.4712e-01, -5.6601e-02, -3.3671e-01,  1.4727e-01, -3.8842e-01,
#            -7.2642e-02,  1.0785e-02, -8.5888e-02, -9.7057e-02,  6.8577e-02,
#            -2.1138e-01, -3.1744e-01, -9.9546e-02,  5.8945e-02, -1.4529e-01,
#            -2.8463e-01,  1.7565e-01,  8.8612e-02,  2.7813e-01, -2.8434e-01,
#            -5.5287e-03, -1.2087e-01, -2.8465e-01, -2.9107e-01, -7.8076e-02,
#            -1.6475e-02,  1.0866e-01, -1.5252e-02,  8.5829e-03, -7.5386e-02,
#             1.1266e-02,  1.1725e-01, -1.9154e-01, -2.8756e-01, -6.2185e-02,
#            -3.7342e-01, -1.5422e-01, -2.6581e-01, -2.3885e-01, -3.0657e-01,
#             9.8259e-02, -1.9715e-01, -2.3198e-01, -1.1226e-01, -4.5561e-02,
#            -4.3542e-02,  2.3098e-01,  1.8973e-01, -1.7024e-01,  1.7556e-01,
#            -2.1667e-01, -3.4515e-01, -8.9693e-02,  8.4541e-02, -2.6025e-01,
#             2.4140e-01,  1.0038e-03,  7.2045e-02, -1.3339e-01,  2.5733e-01,
#            -2.7677e-01, -4.9459e-02,  1.0350e-02,  3.9658e-01, -1.8708e-01,
#             1.6934e-01, -8.9849e-02, -1.5731e-01, -5.7400e-02, -3.1098e-01,
#            -3.0482e-01, -1.8622e-01, -1.1058e-01, -4.5275e-01,  4.9831e-01,
#            -2.0960e-01,  6.6319e-02, -1.2948e-01,  6.7824e-02, -2.2399e-02,
#            -1.8267e-01,  2.1341e-01, -5.7631e-01,  4.6456e-01, -3.5891e-01,
#            -1.5349e-01,  4.8344e-02,  2.3644e-01,  9.9033e-02, -3.3256e-01,
#            -3.3889e-01, -4.0135e-01, -5.7800e-02,  2.7089e-01, -4.0657e-01,
#             2.7780e-01, -2.0439e-01, -2.0986e-01, -1.9784e-02, -1.6946e-01,
#             1.4010e-01,  1.4360e-01,  3.6470e-01, -3.4813e-01,  1.0580e-02,
#            -2.8904e-01,  6.6704e-02, -3.6582e-01,  9.9548e-02, -1.2064e-01,
#             1.6971e-01, -1.4856e-01, -3.1680e-01, -3.4261e-01, -2.4982e-01,
#            -2.3512e-02,  6.2750e-01,  2.9889e-01, -1.8525e-01,  5.1774e-02,
#             4.0773e-01,  3.6474e-01,  2.2523e-01, -1.3815e-01,  1.2659e-01,
#            -8.7812e-02, -2.7771e-01,  1.1416e-01,  2.5095e-01, -5.6425e-02,
#             4.1188e-02, -2.0821e-01, -1.1482e-01,  5.2136e-01,  3.7761e-01,
#             4.2264e-02,  3.2867e-04, -4.2624e-01,  7.4967e-02,  7.7639e-02,
#             2.2245e-01, -2.4992e-01, -1.0643e-01, -2.5545e-01, -2.2117e-01,
#             5.3060e-01, -3.5745e-01, -2.3028e-01, -1.8829e-01,  1.2730e-01,
#            -2.1949e-01,  1.5285e-01,  2.2608e-01,  4.4303e-02, -1.0250e-01,
#             3.5176e-01,  2.2992e-01, -4.2624e-02, -1.3632e-01, -3.1294e-02,
#            -5.2287e-01,  2.5348e-01, -1.0307e-01, -1.8594e-01,  2.0378e-02,
#            -1.7650e-01, -3.7057e-01, -1.2834e-01,  1.8020e-01, -1.1277e-01,
#            -1.0832e-01, -1.6478e-02, -1.0132e-01,  2.9008e-01,  4.8882e-01,
#            -9.9773e-02,  1.4751e-01,  1.6953e-01, -6.1047e-02, -1.0503e-01,
#             3.5710e-01,  1.7059e-01,  1.6282e-01,  2.5686e-02,  1.8939e-01,
#             2.4638e-01,  1.4582e-01,  9.1870e-02, -1.8447e-01,  7.2647e-03,
#            -2.9838e-01,  2.0958e-01,  4.2366e-01,  1.8805e-02, -3.2829e-01,
#             2.8739e-01,  9.9630e-02,  6.4524e-02,  1.6432e-02, -3.8337e-01,
#             3.7819e-02, -8.7955e-02, -3.6561e-01, -1.2260e-01, -3.3557e-01,
#            -1.0144e-01, -5.5638e-01,  2.7686e-01, -3.7120e-01,  2.1502e-01,
#             2.8581e-01,  2.3454e-02, -3.5376e-01, -2.4376e-02, -1.7802e-01,
#            -1.5986e-01,  2.8918e-01,  2.7553e-01,  6.7894e-02, -2.7133e-01,
#            -1.8684e-02, -2.2843e-02, -1.5661e-01,  1.3944e-02, -7.9483e-02,
#            -2.5778e-01, -1.9061e-01, -1.9432e-01,  2.0592e-01, -3.2525e-01,
#             2.4152e-01, -2.0053e-01,  1.1447e-01,  1.4543e-01,  4.0563e-02,
#             4.0544e-02, -8.7982e-02,  7.2792e-02,  5.4680e-01, -3.6577e-01,
#            -2.0945e-01,  7.4037e-02, -3.5209e-02,  1.6205e-01,  4.5230e-03,
#            -8.3912e-02,  1.9008e-01,  2.2880e-01, -4.5180e-01, -2.0295e-01,
#            -3.0812e-01,  4.6400e-01,  4.8174e-01,  2.5007e-01,  2.2207e-01,
#            -3.6784e-02, -2.6977e-01,  3.9546e-01, -1.4881e-01,  7.1256e-03,
#            -2.8217e-01,  6.4049e-01,  1.7141e-01, -2.0263e-01,  4.6169e-02,
#             2.2118e-01, -2.1691e-01, -4.9853e-02,  2.3833e-01,  8.6357e-02,
#            -1.0783e-01,  1.5582e-01,  2.2146e-02,  1.6088e-01, -1.7629e-01,
#            -1.9106e-02,  3.5123e-01,  3.9874e-02, -2.6563e-01, -3.4972e-01,
#             1.8299e-01,  5.1994e-03, -2.0523e-01, -1.9081e-01, -2.7711e-01,
#            -1.8223e-01, -2.0934e-01, -2.3592e-01, -8.3421e-02, -2.9532e-01,
#             3.2778e-01, -2.2677e-02,  1.4017e-01, -6.2008e-02, -1.2713e-02,
#            -8.1851e-02,  4.9118e-03,  6.6192e-02,  3.3319e-01,  3.1661e-01,
#            -1.3141e-01,  2.3329e-01, -4.4902e-01, -2.8373e-01,  1.4872e-01,
#             1.1923e-01, -1.6882e-01,  3.0270e-01,  4.5547e-02,  5.9902e-01,
#            -2.3891e-02, -3.2540e-01,  5.8778e-01,  4.5990e-01,  7.8934e-02,
#            -1.3431e-01, -2.3988e-02, -2.0697e-01,  1.2262e-01,  2.5890e-01,
#            -1.2423e-01,  8.0374e-02,  1.5651e-01, -3.7601e-02, -2.0720e-01,
#             6.0236e-02, -1.2059e-01,  2.8424e-01,  6.3535e-02,  2.4028e-01,
#            -5.2206e-01, -2.8446e-01, -4.6634e-01,  3.6918e-01,  1.4328e-01,
#            -6.3064e-02, -6.0600e-02, -3.7576e-01, -1.4034e-01, -1.1784e-01,
#            -1.4532e-04, -7.1631e-02, -3.0054e-01, -4.5118e-01,  1.9736e-02,
#             1.8120e-01,  1.8370e-01, -1.5414e-01,  1.9897e-02, -2.5032e-01,
#             7.2438e-02,  7.0005e-03,  3.5347e-02,  2.4948e-01, -2.7804e-01,
#             6.7040e-02,  6.2936e-02,  6.6523e-02,  2.6790e-01,  4.1934e-01,
#             2.1956e-01, -1.4615e-01,  1.2694e-01,  6.1882e-02, -8.7219e-02,
#             2.7024e-01,  7.1521e-02,  2.0079e-01, -2.7855e-01,  4.5327e-01,
#            -2.8713e-01,  1.9685e-01,  1.0669e-02, -4.7847e-02, -2.1987e-01,
#            -4.3601e-02, -2.4822e-01, -3.5360e-02, -2.1063e-02,  1.5206e-01,
#             5.7119e-01, -8.3209e-03,  4.3243e-02, -1.3888e-01,  1.5604e-01,
#            -4.4922e-01, -1.8344e-01, -5.1928e-01, -2.0682e-01,  2.0696e-01,
#            -1.2534e-01, -2.7348e-01,  2.2618e-01,  9.9584e-02,  1.7519e-03,
#             2.4192e-01, -8.9279e-03, -5.1577e-02,  3.0629e-02,  1.4262e-01,
#            -1.3331e-01,  7.8583e-02, -1.6612e-01,  2.6420e-01,  2.0943e-01,
#             2.8703e-01,  4.7239e-03,  1.4235e-01, -3.7271e-01,  3.7192e-01,
#            -6.3701e-02, -2.4027e-01,  6.5510e-02, -7.0749e-02,  1.9214e-01,
#            -2.0957e-01,  9.9182e-02, -1.1740e-01,  8.6955e-02, -1.5495e-01,
#            -1.6450e-01,  1.2219e-01, -4.3857e-01,  3.6019e-01,  1.2236e-01,
#            -5.8517e-02,  2.5397e-01, -2.1246e-02,  4.2481e-02,  2.6009e-01,
#             2.9382e-01,  1.2609e-01,  7.2050e-02, -1.9690e-01, -4.0591e-01,
#             2.4792e-01, -3.7980e-01]]], grad_fn=<StackBackward>))

# %%
citerion = nn.NLLLoss()
#sent = sent.unsqueeze(1)
print(sent[0].squeeze(0).shape, output.squeeze(0).shape)

citerion(output.squeeze(0), sent[0].squeeze(0))
# Out:
# torch.Size([1]) torch.Size([1, 7376])
# tensor(0., grad_fn=<NllLossBackward>)
